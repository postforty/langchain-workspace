# %% [markdown]
# ### 음성(오디오) 텍스트로 요약하기

# %%
from google import genai

import os
from dotenv import load_dotenv
load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

client = genai.Client(api_key=gemini_api_key)

MODEL_ID = "gemini-2.5-flash"

# %%
URL = "data/Steve Jobs' 2005 Stanford Commencement Address.mp3"

# %%
your_audio_file = client.files.upload(file=URL)

# %%
response = client.models.generate_content(
  model=MODEL_ID,
  contents=[
    'Listen carefully to the following audio file. Provide a brief summary.',
    your_audio_file,
  ]
)

print(response.text)
# Out:
# The speaker, Steve Jobs, addresses a commencement ceremony at Stanford University, stating he is honored to be there despite never having graduated from college himself. He shares three personal stories:
#
# 1.  **Connecting the Dots:** He recounts dropping out of Reed College but continuing to audit classes, particularly calligraphy. This seemingly impractical pursuit became crucial a decade later when he designed the first Macintosh computer, which featured innovative typography. He emphasizes that you can only connect the dots looking backward, encouraging trust in one's gut and intuition that events will align in the future.
#
# 2.  **Love and Loss:** Jobs speaks about starting Apple at age 20 and being fired from the company he co-founded at 30. Despite the devastation, he realized he still loved his work. This setback ultimately freed him, leading him to start NeXT and Pixar (which created "Toy Story") and to meet his wife. Apple later acquired NeXT, bringing him back to the company. He concludes that finding what you love is essential, and not to settle until you find it.
#
# 3.  **Death:** Jobs reflects on the quote, "If you live each day as if it was your last, someday you'll most certainly be right." He explains how this perspective helps him make important life choices. He shares his recent cancer diagnosis, being told he had only months to live, and his miraculous recovery from a rare, curable form of pancreatic cancer. He advises graduates that time is limited, so they should not waste it living someone else's life, and should follow their heart and intuition as they already know what they truly want.
#
# He concludes by invoking the farewell message from the "Whole Earth Catalog," wishing the graduates to "Stay Hungry, Stay Foolish."

# %%
eng_to_kor = client.models.generate_content(
  model=MODEL_ID,
  contents=[
    '영어로된 본문을 한글로 번역하세요.',
    response.text,
  ]
)

print(eng_to_kor.text)
# Out:
# 스티브 잡스 연사는 스탠퍼드 대학교 졸업식에서 연설하며, 자신은 대학을 졸업한 적이 없음에도 불구하고 이 자리에 서게 되어 영광이라고 말합니다. 그는 세 가지 개인적인 이야기를 들려줍니다:
#
# 1.  **점들을 연결하기:** 그는 리드 칼리지에서 자퇴했지만, 서예 수업을 비롯한 여러 수업을 청강했다고 회상합니다. 당시에는 아무짝에도 쓸모없어 보이던 이 배움이 10년 후, 그가 혁신적인 타이포그래피를 특징으로 하는 최초의 매킨토시 컴퓨터를 디자인할 때 결정적인 역할을 했습니다. 그는 점들은 뒤돌아볼 때만 연결될 수 있다고 강조하며, 미래에 일들이 결국 맞아떨어질 것이라는 자신의 직감과 직관을 믿으라고 격려합니다.
#
# 2.  **사랑과 상실:** 잡스는 20세에 애플을 시작했고, 30세에는 자신이 공동 창업한 회사에서 해고당했다고 이야기합니다. 절망감에도 불구하고 그는 여전히 자신의 일을 사랑한다는 것을 깨달았습니다. 이 좌절은 궁극적으로 그를 자유롭게 하여 NeXT와 픽사("토이 스토리"를 제작)를 설립하고 아내를 만나게 했습니다. 이후 애플은 NeXT를 인수했고, 그는 회사로 돌아오게 됩니다. 그는 자신이 사랑하는 것을 찾는 것이 본질적이며, 찾을 때까지 안주하지 말라고 결론짓습니다.
#
# 3.  **죽음:** 잡스는 "매일을 마지막 날처럼 산다면, 언젠가 당신은 분명히 옳을 것이다"라는 인용문에 대해 이야기합니다. 그는 이 관점이 중요한 삶의 선택을 하는 데 어떻게 도움이 되는지 설명합니다. 그는 최근 암 진단을 받았을 때 몇 달밖에 살지 못할 것이라는 말을 들었지만, 드물고 치료 가능한 형태의 췌장암에서 기적적으로 회복했던 경험을 공유합니다. 그는 졸업생들에게 시간이 한정되어 있으니 다른 사람의 삶을 사느라 낭비하지 말고, 이미 자신이 진정으로 원하는 것을 알고 있으니 자신의 마음과 직관을 따르라고 조언합니다.
#
# 그는 "Whole Earth Catalog"의 작별 메시지를 인용하며 연설을 마무리합니다: "늘 갈망하고, 늘 무모하게 (Stay Hungry, Stay Foolish)."
