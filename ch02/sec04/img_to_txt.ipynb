# %% [markdown]
# # 제목1
# ## 제목2
# ### 제목3
# #### 제목4
# ##### 제목5
# ###### 제목6
#
# **굵은 글씨**
#
# *기울임체*
#
# > https://www.markdownguide.org/cheat-sheet/
#
# ```bash
# # 주피터 노특북 의존성 설치 명령
# uv add ipykernel jupyter jupyterlab
# ```
#
# |이름|나이|
# |---|---|
# |김일남|99|
# |김이남|98|

# %%
print("hello")
# Out:
# hello
