# %% [markdown]
# 명화를 읽어 주는 도슨트 만들기

# %%
from dotenv import load_dotenv
load_dotenv()

from google import genai

client = genai.Client()

# %%
user_input = "내 이름은 김일남이야"

# %%
user_input
# Out:
# '내 이름은 김일남이야'

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=user_input,
)

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""반가워요, **김일남**님! 만나서 정말 반갑습니다.
#
# 성함이 아주 정감 있고 멋지시네요. 혹시 제가 도와드릴 일이 있을까요? 아니면 저와 재미있는 대화를 나누고 싶으신가요? 말씀만 하세요! 😊""",
#             thought_signature=b'\x12\xc1\x0c\n\xbe\x0c\x01\xbe>\xf6\xfb\x9a\x80\x1e\xbf\xc2\xec\xdd\xd0\x1eW\x8b^z\xaa\xdb\xd9\xe2\x94\x11\xd9wqo@\xd5{\xbe5\xb8\xa7/\xbfyf\xe1\xf1\xff\xb2\x0cO\xf5Yxc\x99G\x0e\x04#\xe9\xf7\x15\xcc\xc4\xfb\xc9\xdf0i\x84\t\x96\xdb_\xfa^\xe4\xff\x97PLo[\xd2i\xd5\x9b\xef\x0ea\x9c\xfa%\x1bM\xec...'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-3-flash-preview',
#   response_id='vOarabf-KLrH2roPzObO-A4',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=61,
#     prompt_token_count=8,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=8
#       ),
#     ],
#     thoughts_token_count=405,
#     total_token_count=474
#   )
# )
