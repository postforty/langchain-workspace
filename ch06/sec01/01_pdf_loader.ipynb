# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("../data/Employee_Benefits_Guide_2026_v1.pdf")
docs = loader.load()

# %%
docs[0].metadata
# Out:
# {'producer': 'Microsoft: Print To PDF',
#  'creator': 'PyPDF',
#  'creationdate': '2026-01-16T00:25:28+09:00',
#  'author': '',
#  'moddate': '2026-01-16T00:25:28+09:00',
#  'title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx',
#  'source': '../data/Employee_Benefits_Guide_2026_v1.pdf',
#  'total_pages': 22,
#  'page': 0,
#  'page_label': '1'}

# %%
print(docs[3].page_content)
# Out:
# 대표이사 사장 이강철
# 1.2 기업 미션 및 비전
#  Mission: 정밀 기술로 세상을 빈틈없이 연결한다.
#  Vision 2030: 글로벌 Top 5 정밀 기계 부품 솔루션 기업 도약.
#  Slogan: Build Future, Build Steel.
# 1.3 핵심 가치 : T-SPIRIT
# 우리 테크노빌드 인이 일하는 방식이자 의사결정의 기준입니다.
# 1. Trust (신뢰): 동료와 고객에게 정직하고 투명하게 행동한다.
# 2. Specialty (전문성): 자신의 분야에서 대체 불가능한 전문가가 된다.
# 3. Passion (열정): 실패를 두려워하지 않고 끊임없이 도전한다.
# 4. Innovation (혁신): 기존의 방식에 의문을 제기하고 더 나은 방법을 찾는다.
# 5. Respect (존중): 서로의 다양성을 인정하고 배려한다.
# 6. Teamwork (협력): 혼자 빨리 가기보다 함께 멀리 간다.
# 7. Tech (기술): 기술이 우리의 근본임을 잊지 않는다.
#
# 2. 인사 및 평가 제도 (HR System)
# 2.1 직급 및 호칭 체계
# 테크노빌드는 능력 중심의 수평적 조직 문화를 지향하며 직급 단계를 단순화했습니다.
# 직군 구분 직급 단계 체류 연한 (표준) 호칭 표기 비고
# 사무/연구직
# (G직군)
# G1 (Associate) 3년 프로/연구원 대졸 신입 ~
# 사원급
#  G2 (Specialist) 4년 프로/연구원 대리 ~ 과장급
#  G3 (Expert) 5년 책임/선임 차장급
#  G4 (Master) - 수석/책임 부장급 이상

# %% [markdown]
# ---

# %%
from langchain_community.document_loaders import PDFPlumberLoader

loader = PDFPlumberLoader("../data/Employee_Benefits_Guide_2026_v1.pdf")
docs = loader.load()

# %%
docs[0].metadata
# Out:
# {'source': '../data/Employee_Benefits_Guide_2026_v1.pdf',
#  'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf',
#  'page': 0,
#  'total_pages': 22,
#  'Author': '',
#  'CreationDate': "D:20260116002528+09'00'",
#  'ModDate': "D:20260116002528+09'00'",
#  'Producer': 'Microsoft: Print To PDF',
#  'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}

# %%
print(docs[3].page_content)
# Out:
# 대표이사 사장 이강철
# 1.2 기업 미션 및 비전
#  Mission: 정밀 기술로 세상을 빈틈없이 연결한다.
#  Vision 2030: 글로벌 Top 5 정밀 기계 부품 솔루션 기업 도약.
#  Slogan: Build Future, Build Steel.
# 1.3 핵심 가치 : T-SPIRIT
# 우리 테크노빌드 인이 일하는 방식이자 의사결정의 기준입니다.
# 1. Trust (신뢰): 동료와 고객에게 정직하고 투명하게 행동한다.
# 2. Specialty (전문성): 자신의 분야에서 대체 불가능한 전문가가 된다.
# 3. Passion (열정): 실패를 두려워하지 않고 끊임없이 도전한다.
# 4. Innovation (혁신): 기존의 방식에 의문을 제기하고 더 나은 방법을 찾는다.
# 5. Respect (존중): 서로의 다양성을 인정하고 배려한다.
# 6. Teamwork (협력): 혼자 빨리 가기보다 함께 멀리 간다.
# 7. Tech (기술): 기술이 우리의 근본임을 잊지 않는다.
# 2. 인사 및 평가 제도 (HR System)
# 2.1 직급 및 호칭 체계
# 테크노빌드는 능력 중심의 수평적 조직 문화를 지향하며 직급 단계를 단순화했습니다.
# 직군 구분 직급 단계 체류 연한 (표준) 호칭 표기 비고
# G1 (Associate)
# 사무/연구직 3 년 프로/연구원 대졸 신입 ~
# (G 직군) 사원급
# G2 (Specialist)
# 4 년 프로/연구원 대리 ~ 과장급
# G3 (Expert)
# 5 년 책임/선임 차장급
# G4 (Master) -
# 수석/책임 부장급 이상

# %% [markdown]
# ---

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader("../data/Employee_Benefits_Guide_2026_v1.pdf")
docs = loader.load()

# %%
docs[3].metadata
# Out:
# {'producer': 'Microsoft: Print To PDF',
#  'creator': '',
#  'creationdate': '2026-01-16T00:25:28+09:00',
#  'source': '../data/Employee_Benefits_Guide_2026_v1.pdf',
#  'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf',
#  'total_pages': 22,
#  'format': 'PDF 1.7',
#  'title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'moddate': '2026-01-16T00:25:28+09:00',
#  'trapped': '',
#  'modDate': "D:20260116002528+09'00'",
#  'creationDate': "D:20260116002528+09'00'",
#  'page': 3}

# %%
print(docs[3].page_content)
# Out:
# 대표이사 사장 이강철
# 1.2 기업 미션 및 비전
#  Mission: 정밀 기술로 세상을 빈틈없이 연결한다.
#  Vision 2030: 글로벌 Top 5 정밀 기계 부품 솔루션 기업 도약.
#  Slogan: Build Future, Build Steel.
# 1.3 핵심 가치 : T-SPIRIT
# 우리 테크노빌드 인이 일하는 방식이자 의사결정의 기준입니다.
# 1. Trust (신뢰): 동료와 고객에게 정직하고 투명하게 행동한다.
# 2. Specialty (전문성): 자신의 분야에서 대체 불가능한 전문가가 된다.
# 3. Passion (열정): 실패를 두려워하지 않고 끊임없이 도전한다.
# 4. Innovation (혁신): 기존의 방식에 의문을 제기하고 더 나은 방법을 찾는다.
# 5. Respect (존중): 서로의 다양성을 인정하고 배려한다.
# 6. Teamwork (협력): 혼자 빨리 가기보다 함께 멀리 간다.
# 7. Tech (기술): 기술이 우리의 근본임을 잊지 않는다.
#
# 2. 인사 및 평가 제도 (HR System)
# 2.1 직급 및 호칭 체계
# 테크노빌드는 능력 중심의 수평적 조직 문화를 지향하며 직급 단계를 단순화했습니다.
# 직군 구분
# 직급 단계
# 체류 연한 (표준)
# 호칭 표기
# 비고
# 사무/연구직
# (G 직군)
# G1 (Associate)
# 3 년
# 프로/연구원
# 대졸 신입 ~
# 사원급
#
# G2 (Specialist)
# 4 년
# 프로/연구원
# 대리 ~ 과장급
#
# G3 (Expert)
# 5 년
# 책임/선임
# 차장급
#
# G4 (Master)
# -
# 수석/책임
# 부장급 이상
