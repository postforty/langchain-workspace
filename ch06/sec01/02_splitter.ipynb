# %% [markdown]
# ### Text splitters

# %% [markdown]
# > https://docs.langchain.com/oss/python/integrations/splitters

# %%
# uv add langchain-community pdfplumber
from langchain_community.document_loaders import PDFPlumberLoader

loader = PDFPlumberLoader("../data/Employee_Benefits_Guide_2026_v1.pdf")
documents = loader.load()

# %%
len(documents)
# Out:
# 22

# %%
type(documents[0])
# Out:
# langchain_core.documents.base.Document

# %%
# uv add langchain-text-splitters
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=100)
texts = text_splitter.split_documents(documents)

# %%
len(texts)
# Out:
# 58

# %%
texts
# Out:
# [Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 0, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='2026 년 테크노빌드 주식회사(TechnoBuild) 임직원\n통합 가이드북\n문서 번호: TB-HR-2026-001 (Rev 5.0)\n발행일: 2026 년 1 월 15 일\n적용 대상: 테크노빌드 전 임직원 (정규직, 계약직, 파견직 포함)\n주관 부서: 인사문화본부 (HR Culture Division)\n보안 등급: 대외비 (Internal Use Only)\n[목 차]\n1. 회사 개요 (Company Overview)\no 1.1 CEO 인사말\no 1.2 기업 미션 및 비전\no 1.3 핵심 가치 : T-SPIRIT\no 1.4 조직도 및 본부 소개\n2. 인사 및 평가 제도 (HR System)\no 2.1 직급 및 호칭 체계\no 2.2 승진 포인트 제도 (Tech-Point)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 0, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='o 1.4 조직도 및 본부 소개\n2. 인사 및 평가 제도 (HR System)\no 2.1 직급 및 호칭 체계\no 2.2 승진 포인트 제도 (Tech-Point)\no 2.3 성과 평가 (T-MBO) 프로세스\no 2.4 전문직군 전환 제도 (Dual Ladder)\n3. 근무 및 복무 관리 (Work & Duty)\no 3.1 표준 근무 시간 및 유연 근무제\no 3.2 생산직 교대 근무 (T-Shift) 운영 규정\no 3.3 시간외 근무 및 특근 신청 절차\no 3.4 휴가 제도 상세 (연차, 공가, 병가, 청원 휴가 등)\no 3.5 하이브리드 및 재택 근무 가이드 (Hybrid Work Policy)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 1, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='4. 급여 및 보상 체계 (Compensation)\no 4.1 연봉 구조 및 지급 시기\no 4.2 성과급 (PI/PS) 지급 기준\no 4.3 제수당 항목 및 계산식 상세\no 4.4 특수 영입 및 장기 근속 보너스 (Signing Bonus)\no 4.5 인재 추천 리워드 프로그램 (Referral Guide)\no 4.6 전략적 주식 보상 제도 (Stock Option & RSU)\n5. 복리후생 I : 생활 및 금융 지원 (Life Support)\no 5.1 자녀 학자금 지원 (Future Builder)\no 5.2 주거 안정 자금 대출 (Sweet Home)\no 5.3 선택적 복지 포인트 (TB Wellness Mall)\no 5.4 경조사 지원 기준 (휴가 및 경조금)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 1, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='o 5.2 주거 안정 자금 대출 (Sweet Home)\no 5.3 선택적 복지 포인트 (TB Wellness Mall)\no 5.4 경조사 지원 기준 (휴가 및 경조금)\no 5.5 다양성 및 포용성 지원 (DEIB & Diversity)\n6. 복리후생 II : 건강 및 근무 환경 (Health & Env)\no 6.1 건강 검진 및 의료비 지원\no 6.2 구내 식당(Food Tech) 이용 안내\no 6.3 통근 버스 노선 및 시간표\no 6.4 근무복 및 안전 장구 지급 기준\no 6.5 전인적 웰니스 서비스 (EAP & Mental Health)\n7. 인재 육성 및 교육 (Learning & Dev)\no 7.1 TB Tech University 커리큘럼\no 7.2 자격증 취득 지원 및 수당'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 1, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='7. 인재 육성 및 교육 (Learning & Dev)\no 7.1 TB Tech University 커리큘럼\no 7.2 자격증 취득 지원 및 수당\no 7.3 해외 연수 프로그램 (Global Explorer)\n8. 윤리 경영 및 보안 (Ethics & Security)\no 8.1 직장 내 괴롭힘 방지 가이드\no 8.2 정보 보안 및 문서 관리 등급\no 8.3 내부 고발 제도 (Clean-TB 핫라인)\n9. 부록 (Appendix)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 2, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='o 9.1 전국 사업장 연락처\no 9.2 제휴 리조트 목록\no 9.3 FAQ (자주 묻는 질문) 심화편\no 9.4 문서 개정 이력 (Revision History)\n10. 법정 복리후생 (Statutory Benefits)\no 10.1 4 대 사회보험 운영 안내\no 10.2 모성보호 및 일·가정 양립 지원\no 10.3 퇴직연금 제도 (DB/DC)\n11. 운영 관리 및 법적 성격 (Policy Administration)\no 11.1 본 가이드의 법적 지위\no 11.2 제도의 변경 및 개정 절차\no 11.3 해석의 우선순위 및 적용 원칙\n12. 심화 보상 매트릭스 (Advanced Reward Matrix)\no 12.1 직급/등급/근속별 성과급 산정 요율\no 12.2 다중 조건부 가산금 규정'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 2, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='12. 심화 보상 매트릭스 (Advanced Reward Matrix)\no 12.1 직급/등급/근속별 성과급 산정 요율\no 12.2 다중 조건부 가산금 규정\n13. 복합 연차 시뮬레이션 (Leave Simulation)\no 13.1 가산 연차 및 안식 휴가 산정 공식\no 13.2 상황별 휴가 계산 시나리오 예시\n1. 회사 개요 (Company Overview)\n1.1 CEO 인사말\n“강철 같은 제품은 직원의 강철 같은 의지에서 나옵니다.”\n사랑하는 테크노빌드 가족 여러분, 2026 년은 우리 회사가 ’스마트 팩토리 3.0’으로\n도약하는 원년입니다. 회사의 성장은 여러분의 행복과 직결되어야 합니다. 올해는 특히\n현장에서 땀 흘리는 생산직 직원들과 연구소의 엔지니어들을 위한 맞춤형 복지를 대폭'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 2, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='도약하는 원년입니다. 회사의 성장은 여러분의 행복과 직결되어야 합니다. 올해는 특히\n현장에서 땀 흘리는 생산직 직원들과 연구소의 엔지니어들을 위한 맞춤형 복지를 대폭\n강화했습니다. 우리는 단순히 부품을 만드는 회사가 아니라, 미래 산업의 근간을 만드는\n기업입니다. 이 가이드북이 여러분의 회사 생활에 든든한 나침반이 되기를 바랍니다.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 3, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='대표이사 사장 이강철\n1.2 기업 미션 및 비전\n\uf0b7 Mission: 정밀 기술로 세상을 빈틈없이 연결한다.\n\uf0b7 Vision 2030: 글로벌 Top 5 정밀 기계 부품 솔루션 기업 도약.\n\uf0b7 Slogan: Build Future, Build Steel.\n1.3 핵심 가치 : T-SPIRIT\n우리 테크노빌드 인이 일하는 방식이자 의사결정의 기준입니다.\n1. Trust (신뢰): 동료와 고객에게 정직하고 투명하게 행동한다.\n2. Specialty (전문성): 자신의 분야에서 대체 불가능한 전문가가 된다.\n3. Passion (열정): 실패를 두려워하지 않고 끊임없이 도전한다.\n4. Innovation (혁신): 기존의 방식에 의문을 제기하고 더 나은 방법을 찾는다.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 3, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='3. Passion (열정): 실패를 두려워하지 않고 끊임없이 도전한다.\n4. Innovation (혁신): 기존의 방식에 의문을 제기하고 더 나은 방법을 찾는다.\n5. Respect (존중): 서로의 다양성을 인정하고 배려한다.\n6. Teamwork (협력): 혼자 빨리 가기보다 함께 멀리 간다.\n7. Tech (기술): 기술이 우리의 근본임을 잊지 않는다.\n2. 인사 및 평가 제도 (HR System)\n2.1 직급 및 호칭 체계\n테크노빌드는 능력 중심의 수평적 조직 문화를 지향하며 직급 단계를 단순화했습니다.\n직군 구분 직급 단계 체류 연한 (표준) 호칭 표기 비고\nG1 (Associate)\n사무/연구직 3 년 프로/연구원 대졸 신입 ~\n(G 직군) 사원급\nG2 (Specialist)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 3, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='직군 구분 직급 단계 체류 연한 (표준) 호칭 표기 비고\nG1 (Associate)\n사무/연구직 3 년 프로/연구원 대졸 신입 ~\n(G 직군) 사원급\nG2 (Specialist)\n4 년 프로/연구원 대리 ~ 과장급\nG3 (Expert)\n5 년 책임/선임 차장급\nG4 (Master) -\n수석/책임 부장급 이상'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 4, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='T1 (Technician)\n생산/기술직 2 년 사원 고졸/초대졸\n(T 직군) 신입\nT2 (Junior -\n3 년 주임\nMeister)\nT3 (Senior\n4 년 기장 조장 역할 수행\nMeister)\nT4 (Grand -\n명장 반장/직장 역할\nMeister)\n수행\n\uf0b7 팀장 (Unit Leader): 직책자로 임명된 경우 ‘팀장’ 호칭 사용.\n\uf0b7 승진 포인트 미달 시: 표준 체류 연한이 지나도 승진 누락될 수 있음.\n2.2 승진 포인트 제도 (Tech-Point)\n승진을 위해서는 각 직급별 필수 Tech-Point 를 획득해야 합니다.\n\uf0b7 구성: 성과 점수(60%) + 역량 점수(30%) + 가점(10%)\n\uf0b7 가점 항목:\no 어학 등급(OPIc/TOEIC Speaking) IM2 이상 : +5 점'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 4, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='\uf0b7 구성: 성과 점수(60%) + 역량 점수(30%) + 가점(10%)\n\uf0b7 가점 항목:\no 어학 등급(OPIc/TOEIC Speaking) IM2 이상 : +5 점\no 직무 관련 기사 자격증 취득 : 개당 +3 점\no 사내 제안 제도 채택 : 건당 +1 점 (최대 5 점)\no 사회 봉사 활동 20 시간 이상 : +2 점\n2.3 성과 평가 (T-MBO) 프로세스\n매년 1 회 정기 평가를 통해 연봉 인상률과 성과급을 결정합니다.\n1. 목표 설정 (2 월): 조직 목표에 따른 개인별 KPI 설정 (팀장 합의)\n2. 중간 점검 (7 월): 상반기 실적 리뷰 및 목표 수정 (Coaching Session)\n3. 최종 평가 (12 월): 달성도 정량/정성 평가'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 4, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='2. 중간 점검 (7 월): 상반기 실적 리뷰 및 목표 수정 (Coaching Session)\n3. 최종 평가 (12 월): 달성도 정량/정성 평가\n4. 등급 부여 (1 월): S(10%), A(30%), B(45%), C(10%), D(5%) 상대 평가 원칙\n평가 이의 신청 제도: 평가 결과 통보 후 7 일 이내 HR 팀에 ‘이의 신청서’ 제출\n가능. 인사위원회 심의를 거쳐 결과 재산정 (단, 무분별한 신청 시 기각)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 5, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='3. 근무 및 복무 관리 (Work & Duty)\n3.1 근무 시간\n\uf0b7 기본 근무: 주 5 일, 1 일 8 시간 (09:00 ~ 18:00), 휴게시간 1 시간 (12:00 ~ 13:00)\n\uf0b7 선택적 근로시간제 (사무/연구직):\no 월 단위 정산 기간 내에서 근무 시간 자율 조정.\no Core Time (필수 근무): 10:00 ~ 15:00\no 1 일 최소 4 시간 이상, 최대 12 시간 이하 근무.\n3.2 생산직 교대 근무 (T-Shift)\n생산 효율 최적화 및 근로자 건강 보호를 위한 3 조 2 교대 시스템입니다.\n\uf0b7 근무 패턴: 4 일 주간 - 2 일 휴무 - 4 일 야간 - 2 일 휴무\n\uf0b7 근무 시간대:\no 주간조 (Day Shift): 08:00 ~ 20:00 (잔업 2 시간 포함)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 5, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='\uf0b7 근무 패턴: 4 일 주간 - 2 일 휴무 - 4 일 야간 - 2 일 휴무\n\uf0b7 근무 시간대:\no 주간조 (Day Shift): 08:00 ~ 20:00 (잔업 2 시간 포함)\no 야간조 (Night Shift): 20:00 ~ 08:00 (잔업 2 시간 포함)\n\uf0b7 식사 시간: 각 조별 1 시간 (중식/석식 또는 조식/석식), 간식 시간 30 분 별도 부여.\n3.3 휴가 제도 상세\n근로기준법을 상회하는 테크노빌드만의 휴가 정책입니다.\nA. 연차 유급 휴가\n\uf0b7 발생 기준:\no 1 년 미만: 1 개월 개근 시 1 일 발생.\no 1 년 이상: 15 일 발생 + 매 2 년마다 1 일 가산 (최대 25 일).\n\uf0b7 사용 촉진: 연차 사용 촉진 제도 시행 (미사용 수당 지급 원칙이나, 7 월/10 월 촉진'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 5, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='o 1 년 이상: 15 일 발생 + 매 2 년마다 1 일 가산 (최대 25 일).\n\uf0b7 사용 촉진: 연차 사용 촉진 제도 시행 (미사용 수당 지급 원칙이나, 7 월/10 월 촉진\n통보 후 미사용 시 소멸).\nB. 리프레시 휴가 (Refres-T)\n장기 근속자의 재충전을 위한 특별 휴가입니다.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 6, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='근속 연수 휴가 기간 지원금 및 혜택\n만 3 년 5 일 (유급) 웰니스 포인트 80 만P\n만 5 년 10 일 (유급) 휴가비 100 만원 + 120 만P\n만 7 년 15 일 (유급) 휴가비 200 만원 + 150 만P\n만 10 년 1 개월 (안식월) 휴가비 300 만원 + 200 만P + 부부\n동반 건강검진권\n3.5 하이브리드 및 재택 근무 가이드 (Hybrid Work Policy)\n테크노빌드는 업무의 특성에 따라 장소에 구애받지 않는 하이브리드 근무 형태를\n지향합니다.\nA. 근무 유형 및 대상\n1. 전면 재택형: 연구직 중 집중 코딩/설계 업무가 필요한 인원 (주 4 일 이상 재택).\n2. 하이브리드형: 사무직군 (주 2~3 일 재택, 나머지 오피스 근무).'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 6, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='1. 전면 재택형: 연구직 중 집중 코딩/설계 업무가 필요한 인원 (주 4 일 이상 재택).\n2. 하이브리드형: 사무직군 (주 2~3 일 재택, 나머지 오피스 근무).\n3. 현장 중심형: 생산 및 생산관리 직군 (원칙적 오피스 근무, 단 사무 업무 시 거점\n오피스 활용 가능).\nB. 인프라 및 통신비 지원\n\uf0b7 장비 지원 (TB-Set): 신규 재택 전환 시 모션 데스크, 허먼밀러 에어론 의자, 멀티\n모니터 등 인당 최대 200 만원 한도 내 지원 (3 년 이상 사용 시 개인 소유 전환).\n\uf0b7 통신 보조금: 재택 근무일에 대해 일 5,000 원(월 최대 10 만원)의 통신 및 전기료\n실비 지원.\n\uf0b7 거점 오피스 (TB-Base): 해운대 센텀, 서면, 양산역 인근 제휴 공유 오피스를'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 6, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='실비 지원.\n\uf0b7 거점 오피스 (TB-Base): 해운대 센텀, 서면, 양산역 인근 제휴 공유 오피스를\n자유롭게 예약하여 근무 가능 (사내 앱 ‘TB-Space’ 예약).\nC. 재택 근무 수칙\n\uf0b7 업무 집중 시간: Core Time(10:00~15:00)에는 메신저 및 화상 회의 상시 응답 대기.\n\uf0b7 보안 준수: 공공 Wi-Fi 사용 금지, 사내 VPN 강제 적용 및 화면 보안 필름 사용 의무.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 7, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='4. 급여 및 보상 체계 (Compensation)\n4.1 연봉 구조 및 지급일\n\uf0b7 구성:\no 기본급 (Basic Salary) : 매년 인사 평가에 따라 조정.\no 고정 수당 : 직책 수당, 자격 수당 등.\n\uf0b7 지급일: 매월 25 일 (공휴일인 경우 전일 지급).\n\uf0b7 산정 기간: 당월 1 일 ~ 당월 말일 기산.\n4.2 성과급 (Incentive)\n회사의 경영 성과를 직원과 공유합니다.\n\uf0b7 PI (Productivity Incentive): 반기별 목표 생산량 및 품질 지수 달성 시 지급\n(기본급의 0 ~ 100%).\no 지급 시기: 7 월, 1 월\n\uf0b7 PS (Profit Sharing): 연간 영업이익 목표 초과 달성 시, 초과 이익의 20%를 재원으로\n지급 (연봉의 최대 50%).'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 7, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='o 지급 시기: 7 월, 1 월\n\uf0b7 PS (Profit Sharing): 연간 영업이익 목표 초과 달성 시, 초과 이익의 20%를 재원으로\n지급 (연봉의 최대 50%).\no 지급 시기: 익년 2 월\n4.3 제수당 항목 및 상세 (Iron Boost Program)\n수당 명칭 지급 대상 지급 기준 (금액) 비고\n-\n직책 수당 팀장 이상 팀장 30 만원,\n본부장 50 만원 / 월\n기술 수당 기술사/기능장 30 만원 / 월 해당 업무 종사 시\n심야 수당 22:00~06:00 근무자 통상임금의 50% 법정 기준\n가산\n위험 수당 특수 공정 작업자 월 150,000 ~ 공정 등급(A/B)별\n200,000 원 차등\n교대 수당 교대 근무자 전원 월 100,000 원 고정급 형태로 지급'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 8, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='가족 수당 부양 가족이 있는 자 배우자 5 만원, 등본 제출 필수\n자녀당 3 만원 / 월\n4.4 특수 영입 및 장기 근속 보너스 (Signing Bonus)\n테크노빌드는 핵심 기술 인력 확보를 위해 입사 시점에 일시불로 지급되는 사이닝 보너스\n제도를 운영합니다.\nA. 지급 대상 및 금액\n1. 대상: 연구직 G3 이상 또는 사외 특급 기술 자격 보유자 중 채용위원회 승인을 득한\n자.\n2. 지급액: 전 직장 연봉의 10% ~ 50% 범위 내에서 개별 협의.\n3. 지급 시기: 입사 첫 달 급여일에 일괄 지급.\nB. 의무 근속 및 환수(Clawback) 조항\n지급 후 36 개월(3 년) 이내에 개인 사유로 퇴사할 경우, 미충족 기간에 대해 월할 계산하여\n반환해야 합니다.\n(36−실제근속개월수)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 8, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='지급 후 36 개월(3 년) 이내에 개인 사유로 퇴사할 경우, 미충족 기간에 대해 월할 계산하여\n반환해야 합니다.\n(36−실제근속개월수)\n환수 금액 = 기지급액×\n36\n알림: 본인 귀책 사유에 의한 징계 해고 시에는 기간에 관계없이 전액 반환을\n원칙으로 합니다.\n4.5 인재 추천 리워드 프로그램 (Internal Referral)\n임직원의 네트워크를 활용한 우수 인재 영입 시 추천인에게 포상금을 지급합니다.\nA. 추천 대상별 보상금 기준\n영입 대상 등급 보상 금액 (합계) 1 차 지급 (수습종료) 2 차 지급 (1 년경과)\nS 급 1,000 만원 500 만원 500 만원\n(핵심인재/임원\n급)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 9, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='A 급 (경력직 G3 500 만원 200 만원 300 만원\n이상)\nB 급 (일반 300 만원 100 만원 200 만원\n경력직)\nC 급 100 만원 50 만원 50 만원\n(신입/T 직군)\nB. 지급 조건 및 제한\n\uf0b7 지급 조건: 피추천인이 입사 후 각 지급 시점에 재직 중이어야 하며, 추천인 또한\n재직 중이어야 함.\n\uf0b7 제한 사항: 인사팀 소속 직원, 해당 부서 팀장 및 채용 면접관은 추천 보상 대상에서\n제외됨.\n4.6 전략적 주식 보상 제도 (Stock Option & RSU)\n구성원의 주인의식을 고취하고 장기 성과를 공유하기 위해 주식 보상 제도를 운영합니다.\nA. 스톡옵션 (Stock Option) 부여 및 행사\n1. 부여 대상: 직전 성과 등급 S 등급 달성자 또는 사내 핵심 R&D 리더.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 9, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='A. 스톡옵션 (Stock Option) 부여 및 행사\n1. 부여 대상: 직전 성과 등급 S 등급 달성자 또는 사내 핵심 R&D 리더.\n2. 행사가액: 부여 시점의 자본시장법상 시가 또는 이사회 결정 가액.\n3. 베스팅(Vesting) 스케줄:\no 2 년 경과 시: 부여 수량의 50% 행사 가능\no 3 년 경과 시: 부여 수량의 25% 추가 행사 가능\no 4 년 경과 시: 잔여 25% 전체 행사 가능 (Full Vesting)\nB. 권리 상실 조건\n\uf0b7 퇴사 시 행사하지 않은 옵션은 자동 소멸함 (단, 명예퇴직이나 회사의 귀책 사유에\n의한 퇴사는 이사회 승인 하에 일정 기간 행사 권리 유지 가능).'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 10, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='5. 복리후생 I : 생활 및 금융 지원 (Life Support)\n5.1 자녀 학자금 지원 (Future Builder Program)\n임직원의 교육비 부담을 경감하여 안정적인 가정 생활을 지원합니다.\n\uf0b7 지급 횟수: 연 4 회 (분기별) 또는 연 2 회 (학기별)\n\uf0b7 신청 시기: 매 분기 말월 1 일 ~ 10 일 (3, 6, 9, 12 월)\n구분 지원 대상 자녀 지원 금액 (한도) 조건 및 서류\n유아 만 4 세 ~ 6 세 월 20 만원 정액 재원 증명서 (매년\n(유치원) 3 월 1 회)\n고등 고등학교 재학생 수업료 및 운영비 납입 고지서\n전액\n대학 정규 2~4 년제 연간 1,000 만원 직전 학기 평점\n대학교 한도 B0(3.0) 이상'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 10, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='(유치원) 3 월 1 회)\n고등 고등학교 재학생 수업료 및 운영비 납입 고지서\n전액\n대학 정규 2~4 년제 연간 1,000 만원 직전 학기 평점\n대학교 한도 B0(3.0) 이상\n장애 자녀 특수 교육 기관 재원 월 50 만원 정액 장애인 증명서, 재원\n증명서\n※ 대학 학자금 상세 규정 (중요) 1. 성적 미달 시: C+ 학점일 경우 50% 지급, C0 이하 또는 F\n학점 포함 시 미지급. * 단, 신입생 첫 학기는 성적 기준 면제. 2. 자녀 수 제한: 없음 (단,\n3 자녀 이상일 경우 3 째부터는 성적 기준 완화 - C0 이상 지급). 3. 해외 대학: 국내 학자금\n한도 내 실비 지원 (환율은 신청일 매매기준율 적용).\n5.2 주거 안정 자금 대출 (Sweet Home Loan)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 10, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='한도 내 실비 지원 (환율은 신청일 매매기준율 적용).\n5.2 주거 안정 자금 대출 (Sweet Home Loan)\n\uf0b7 용도: 주택 구입(본인 명의), 전세/월세 보증금.\n\uf0b7 한도:\no 근속 1~3 년: 3,000 만원\no 근속 3~5 년: 5,000 만원\no 근속 5 년 이상: 최대 1 억원\n\uf0b7 금리: 연 1.5% 고정 금리 (회사 복지 기금에서 이차 보전).'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 11, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='\uf0b7 상환: 2 년 거치 5 년 원리금 균등 분할 상환 (중도 상환 수수료 없음).\n\uf0b7 패널티: 대출 기간 중 퇴사 시, 퇴사일 전일까지 일시 상환 원칙 (미상환 시 퇴직금\n공제 및 법적 조치).\n5.3 테크노 웰니스 포인트 (TB Wellness Mall)\n\uf0b7 지급액: 전 직원 연간 120 만 포인트 (1 월 1 일 일괄 지급).\n\uf0b7 사용처: 사내 복지몰 (TB Mall) 및 제휴 오프라인 매장.\no 건강 관리: 헬스장, 요가, 병원비 결제 가능.\no 자기 계발: 도서 구입, 학원 수강.\no 문화 생활: 영화, 공연 티켓, 여행 상품.\n\uf0b7 소멸: 당해 연도 12 월 31 일까지 미사용 시 자동 소멸 (이월 불가).\n5.4 경조사 지원 기준 (Family Support Details)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 11, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='\uf0b7 소멸: 당해 연도 12 월 31 일까지 미사용 시 자동 소멸 (이월 불가).\n5.4 경조사 지원 기준 (Family Support Details)\n기쁨과 슬픔을 함께 나누는 테크노빌드의 경조 지원입니다.\n구분 대상 휴가 (일수) 경조금 (만원) 화환/조화\n결혼 본인 5 일 100 + 화환 지원\n자녀 1 일 50 + 화환 지원\n30 -\n형제/자매 1 일\n30 -\n회갑/칠순 본인/배우자 부모 1 일\n출산 본인 출산휴가 (90 일) 출산 축하금 50 과일 바구니\n배우자 10 일 (유급) 출산 축하금 50 과일 바구니\n-\n사망 본인/배우자 500 + 장례용품 3 단 조화 + 근조기\n부모/배우자 부모 5 일 100 + 장례용품 3 단 조화 + 근조기\n30\n조부모/외조부모 3 일 조화\n30\n형제/자매 3 일 조화'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 11, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='부모/배우자 부모 5 일 100 + 장례용품 3 단 조화 + 근조기\n30\n조부모/외조부모 3 일 조화\n30\n형제/자매 3 일 조화'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 12, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='5.5 다양성 및 포용성 지원 (DEIB & Diversity)\n모든 구성원의 삶의 방식을 존중하며, 전통적 가족 형태를 넘어선 현대적 복지를\n실현합니다.\nA. 비혼 선언 지원 (Single Life Celebration)\n1. 대상: 만 38 세 이상, 근속 5 년 이상의 임직원 중 비혼을 공식 선언한 자.\n2. 혜택: 결혼 축의금과 동일한 수준의 보상 제공.\no 비혼 축하금 100 만원 지원.\no 리프레시 유급 휴가 5 일 부여.\n3. 제한: 비혼 선언 후 5 년 이내 실제 결혼 시, 기지급된 혜택의 50%를 환수함.\nB. 반려동물 가족 수당 (Pet-Fam Support)\n1. 대상: 반려동물과 함께 거주 중인 임직원 (동물등록증 제출 필수).'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 12, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='B. 반려동물 가족 수당 (Pet-Fam Support)\n1. 대상: 반려동물과 함께 거주 중인 임직원 (동물등록증 제출 필수).\n2. 수당: 마리당 월 3 만원 지급 (최대 2 마리, 총 6 만원 한도).\n3. 특별 혜택: 반려동물 사망 시 1 일 유급 위로 휴가(Rainbow Pass) 부여 및 장례\n지원금 10 만원 지급.\n6. 복리후생 II : 건강 및 근무 환경 (Health & Env)\n6.1 건강 검진 및 의료비\n\uf0b7 일반 검진: 매년 전 직원 실시 (사내 출장 검진 또는 지정 병원 내원).\n\uf0b7 종합 검진 (정밀):\no 만 35 세 이상: 매년 1 회 (본인 + 배우자). 검진비 전액 지원 (인당 40 만원\n상담).\no 만 35 세 미만: 격년(2 년 1 회) 지원.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 12, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='\uf0b7 종합 검진 (정밀):\no 만 35 세 이상: 매년 1 회 (본인 + 배우자). 검진비 전액 지원 (인당 40 만원\n상담).\no 만 35 세 미만: 격년(2 년 1 회) 지원.\no 선택 항목: 위/대장 수면 내시경, 초음파, CT 등 2 개 항목 선택 가능.\n\uf0b7 단체 상해 보험: 업무 중/외 불문 상해 사고 시 실비 지원 (최대 3 천만원).\n6.2 구내 식당 (Food Tech)\n\uf0b7 위치: 본관 B1 층 (Cafe T), 생산동 2 층 (Iron Kitchen).'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 13, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='\uf0b7 운영 시간:\no 조식: 07:00 ~ 08:30 (라면/토스트 코너 운영)\no 중식: 11:30 ~ 13:30 (한식/일식/양식 3 코스 중 택 1)\no 석식: 17:30 ~ 19:00 (특근자 및 야간 근무자용)\no 야식: 23:00 ~ 00:30 (야간조 전용, 고단백 메뉴 위주)\n\uf0b7 비용: 전액 무료 (사원증 태깅 필수).\n6.3 통근 버스 노선표 (2026.01 기준)\n교통 혼잡 완화 및 출퇴근 편의를 위해 부산 및 경남권 주요 거점 셔틀을 운영합니다.\nA. 출근 노선 (회사 도착 기준)\n노선명 출발지 주요 경유지 (시간) 도착 (회사) 비고\n08:30\nA-1 노선 서면역 12 번출구 서면(06:50) → 월~금 운행\n부산역(07:05) →\n사상(07:25)\n08:35'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 13, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='08:30\nA-1 노선 서면역 12 번출구 서면(06:50) → 월~금 운행\n부산역(07:05) →\n사상(07:25)\n08:35\nA-2 노선 해운대역 5 번출구 해운대(06:40) → 월~금 운행\n센텀시티(07:00) →\n수영(07:15)\n08:20\nB-1 노선 덕천역 3 번출구 덕천(07:10) → 배차 간격\n구포(07:25) → 10 분\n강서구청(07:40)\n08:30 -\nC-1 노선 노포동 터미널 터미널(06:40) →\n부산대(07:00) →\n동래(07:20)\n08:20\nD-1 노선 회사 기숙사 기숙사 정문(07:40, 셔틀 수시\n07:50, 08:00, 08:10)\n운행'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 14, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='B. 퇴근 노선 (회사 출발 기준)\n노선명 출발 시간 주요 하차 지점 (예상 비고\n도착 시간)\n18:10\nA-1 (서면행) 사상(18:50) → 정시 퇴근용\n부산역(19:10) →\n서면(19:30)\n20:10\nA-1 (잔업) 사상(20:40) → 잔업/특근용\n부산역(21:00) →\n서면(21:15)\n18:15\nA-2 (해운대행) 수영(19:00) → 금요일 5 분 조출\n센텀시티(19:20) →\n해운대(19:40)\n18:10 -\nB-1 (덕천행) 강서구청(18:30) →\n구포(18:45) →\n덕천(19:00)\n18:10 -\nC-1 (노포행) 동래(19:00) →\n부산대(19:20) →\n노포동(19:40)\n18:10 / 20:10\nD-1 (기숙사) 기숙사 단지 내 각 동 상시 운행\n입구'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 14, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='18:10 -\nC-1 (노포행) 동래(19:00) →\n부산대(19:20) →\n노포동(19:40)\n18:10 / 20:10\nD-1 (기숙사) 기숙사 단지 내 각 동 상시 운행\n입구\n\uf0b7 퇴근 버스는 회사 본관 앞 주차장에서 출발합니다. 모바일 앱 ’TB-Bus’를 통해\n실시간 버스 위치 및 잔여 좌석 확인이 가능합니다.\n6.4 피복 및 안전 장구\n\uf0b7 신규 입사: 동/하복 근무복 각 2 벌, 안전화 1 족, 방한 점퍼 1 벌 지급.\n\uf0b7 정기 지급: 매년 4 월(하복), 10 월(동복/방한복) 신청 받아 지급.\n\uf0b7 파손 교체: 작업 중 파손 시 부서장 확인 후 즉시 교체 (수량 제한 없음).\n\uf0b7 세탁 서비스: 사내 세탁실 무료 운영 (근무복 반납 후 익일 수령).'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 15, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='6.5 전인적 웰니스 서비스 (EAP & Mental Health)\n신체 건강뿐만 아니라 직원의 정신적, 정서적 건강을 케어하는 전문 프로그램을\n운영합니다.\nA. 전문 심리 상담 서비스 (TB-Mind Care)\n1. 내용: 직무 스트레스, 대인 관계, 가족 문제 등 전반적인 심리 상담 지원.\n2. 방법: 외부 전문 상담 기관(EAP) 제휴를 통한 1:1 상담 (대면/화상/전화).\n3. 익명 보장: 상담 내용 및 이용 여부는 회사에 일절 통보되지 않으며, 개인 비밀\n유지를 최우선으로 함.\n4. 비용: 연간 10 회까지 전액 회사 부담.\nB. 사내 명상 및 스트레칭 클래스\n\uf0b7 마인드풀니스 정기 세션: 매주 수요일 점심 시간 본관 강당 운영.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 15, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='유지를 최우선으로 함.\n4. 비용: 연간 10 회까지 전액 회사 부담.\nB. 사내 명상 및 스트레칭 클래스\n\uf0b7 마인드풀니스 정기 세션: 매주 수요일 점심 시간 본관 강당 운영.\n\uf0b7 스트레스 지수 측정: 매 분기 의무실 내 ’마음 건강 키오스크’를 통한 정기 자가 진단\n권장.\n7. 인재 육성 및 교육 (Learning & Dev)\n7.1 TB Tech University\n임직원의 직무 역량 강화를 위해 사내 대학 프로그램을 운영합니다.\n\uf0b7 필수 과정:\no 신입 입문 과정 (T-Rookie): 입사 후 2 주간 합숙 교육.\no 승진자 교육 (Change Agent): 승진 대상자 연 1 회.\no 안전 법정 교육: 매 분기 6 시간 필수 이수 (사이버 연수원).\n\uf0b7 선택 과정:'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 15, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='o 승진자 교육 (Change Agent): 승진 대상자 연 1 회.\no 안전 법정 교육: 매 분기 6 시간 필수 이수 (사이버 연수원).\n\uf0b7 선택 과정:\no AI/Data 분석 과정 (파이썬, R 기초) - 8 주 과정.\no 스마트 팩토리 제어 (PLC 실습) - 4 주 과정.\no 글로벌 비즈니스 영어/중국어/일어 - 조찬 클래스.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 16, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='7.2 자격증 취득 지원\n직무 관련 국가 기술 자격 취득 시 축하금 및 수당을 지급합니다.\n자격 등급 축하금 (1 회성) 자격 수당 (월) 대상 자격증 예시\n기술사/기능장 200 만원 30 만원 금속재료, 용접, 기계가공 등\n기사 50 만원 10 만원 일반기계, 전기, 산업안전 등\n산업기사 30 만원 5 만원 기계설계, 위험물 등\n기능사 10 만원 3 만원 선반, 밀링, 특수용접 등\n\uf0b7 조건: 동일 등급 내 1 개 자격증만 수당 인정 (상위 등급 취득 시 갱신). 축하금은 횟수\n제한 없음.\n7.3 해외 연수 (Global Explorer)\n\uf0b7 대상: 연간 최우수 사원 (MVP) 및 우수 팀.\n\uf0b7 내용: 매년 10 월 독일/일본 등 선진 제조 현장 견학 및 문화 탐방 (7 박 9 일).'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 16, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='\uf0b7 대상: 연간 최우수 사원 (MVP) 및 우수 팀.\n\uf0b7 내용: 매년 10 월 독일/일본 등 선진 제조 현장 견학 및 문화 탐방 (7 박 9 일).\n\uf0b7 비용: 회사 전액 부담 (개인 경비 1,000 유로 별도 지급).\n8. 윤리 경영 및 보안 (Ethics & Security)\n8.1 직장 내 괴롭힘 방지 가이드\n테크노빌드는 상호 존중 문화를 위해 ’직장 내 괴롭힘 Zero’를 선언합니다.\n\uf0b7 금지 행위:\no 폭언, 폭행, 모욕적 언사.\no 정당한 이유 없는 업무 배제 또는 과도한 업무 부여.\no 사적인 심부름 지시, 회식 강요, 음주 강권.\n\uf0b7 신고 채널: HR 팀 핫라인 (내선 9999) 또는 익명 제보 앱 ‘Hear-U’.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 16, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='o 사적인 심부름 지시, 회식 강요, 음주 강권.\n\uf0b7 신고 채널: HR 팀 핫라인 (내선 9999) 또는 익명 제보 앱 ‘Hear-U’.\n\uf0b7 처벌: 가해 사실 확인 시 ‘원 스트라이크 아웃’ (파면 또는 해임) 원칙 적용. 신고자\n신원 철저 보호 및 불이익 금지.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 17, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='8.2 정보 보안 규정\n\uf0b7 보안 등급:\no Level 1 (일반): 사내 게시판 비공개 자료.\no Level 2 (대외비): 부서 내 공유 가능, 외부 유출 시 승인 필요.\no Level 3 (극비): 핵심 기술 도면, 레시피 등. 접근 권한자 외 열람 불가.\n\uf0b7 IT 기기:\no 개인 노트북 반입 금지. 사내 지급 PC 만 사용.\no 스마트폰 카메라 보안 스티커 부착 필수 (생산 라인 및 연구소).\no USB 등 이동식 저장 매체 사용 차단 (승인된 보안 USB 만 사용).\n9. 부록 (Appendix)\n9.1 전국 사업장 안내\n구분 사업장명 주소 대표 전화 주요 기능\n051-123-4567\n본사/1 공장 부산 캠퍼스 부산광역시 본사, R&D,\n강서구 녹산산단 정밀 가공\n382 로 10'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 17, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='구분 사업장명 주소 대표 전화 주요 기능\n051-123-4567\n본사/1 공장 부산 캠퍼스 부산광역시 본사, R&D,\n강서구 녹산산단 정밀 가공\n382 로 10\n055-987-6543\n2 공장 양산 캠퍼스 경상남도 양산시 대형 조립,\n어곡공단1 길 55 물류 센터\n02-3456-7890\n서울 지사 서울 사무소 서울특별시 수도권 영업 및\nCS\n강남구 테헤란로\n123\n051-123-4500\n기숙사 테크노 하우스 부산광역시 임직원 숙소\n강서구 (500 실)\n명지국제로 99'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 18, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='9.2 제휴 휴양소 (Resort Membership)\n임직원 할인가(법인 회원가)로 이용 가능하며, 성수기(7~8 월, 12 월)는 추첨제로\n운영됩니다.\n\uf0b7 한화 리조트: 전국 전 지점 (해운대, 설악, 제주 등).\n\uf0b7 소노 호텔 & 리조트 (구 대명): 비발디파크, 쏠비치 등.\n\uf0b7 켄싱턴 리조트: 설악밸리, 경주 등.\n\uf0b7 신청 방법: 사내 인트라넷 ‘휴양소 신청’ 메뉴 → 희망 날짜 및 지역 선택.\n\uf0b7 추첨 가산점:\no 최근 1 년간 휴양소 미당첨자 (+5 점).\no 다자녀 가구 (3 자녀 이상, +3 점).\no 우수 사원 포상자 (+3 점).\n9.3 FAQ 심화편\nQ: 이번 달에 기술사 자격증을 땄습니다. 수당은 언제부터 나오나요? A: 자격증 사본을'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 18, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='o 우수 사원 포상자 (+3 점).\n9.3 FAQ 심화편\nQ: 이번 달에 기술사 자격증을 땄습니다. 수당은 언제부터 나오나요? A: 자격증 사본을\nHR 팀에 제출한 익월 급여부터 반영됩니다. 만약 1 월 15 일에 제출했다면 2 월 급여\n명세서의 ‘자격 수당’ 항목에서 확인 가능합니다. 축하금(200 만원)은 제출 후 2 주 이내\n별도 입금됩니다.\nQ: 통근 버스를 놓쳤는데 택시비 지원이 되나요? A: 개인의 지각으로 인한 미탑승은\n지원되지 않습니다. 단, 야근 등 업무상 사유로 막차(20:10) 이후 퇴근하거나, 버스 노선이\n없는 지역으로 외근 시에는 ‘법인 카드’ 또는 ’교통비 영수증 청구’가 가능합니다. (팀장\n전결 필요)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 18, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='없는 지역으로 외근 시에는 ‘법인 카드’ 또는 ’교통비 영수증 청구’가 가능합니다. (팀장\n전결 필요)\nQ: 사택(기숙사) 입주 조건은 어떻게 되나요? A: 원거리 거주자(회사 반경 40km 이외 지역\n거주) 및 독신자 우선 배정입니다. 기혼자도 ‘주말 부부’ 등의 사유가 인정되면 입주\n가능합니다. 월 관리비 5 만원은 급여에서 공제되며, 최대 거주 기간은 2 년(1 회 연장 가능,\n최대 4 년)입니다.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 19, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='Q: 의료비 지원에서 치과 치료도 포함되나요? A: 원칙적으로 미용 목적(교정, 미백 등)은\n제외됩니다. 단, 치료 목적의 보철, 임플란트(본인 한정, 연 1 회), 충치 치료 등은\n국민건강보험 급여 항목에 한해 본인 부담금 50%를 지원합니다 (연간 한도 100 만원 내).\nQ: 주재원 발령 시 배우자 어학 교육비도 지원되나요? A: 네, 해외 주재원(1 년 이상\n파견)으로 선정될 경우, 동반 출국하는 배우자에 대해 현지 어학원 수강료를 월 300 달러\n한도 내에서 6 개월간 지원합니다.\n9.4 문서 개정 이력 (Revision History)\n버전 개정일 주요 개정 내용 승인자\nRev 1.0 2025.01.01\n최초 제정 및 시행 (수도권 기반) 이강철\nRev 2.0 2025.07.01'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 19, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='버전 개정일 주요 개정 내용 승인자\nRev 1.0 2025.01.01\n최초 제정 및 시행 (수도권 기반) 이강철\nRev 2.0 2025.07.01\n분량 확장 및 선택적 복지 포인트 이강철\n도입\nRev 3.0 2026.01.01\n본사 부산 이전 반영 및 법정 김인사\n복리후생 섹션 강화\nRev 3.1 2026.01.05\n전략적 보상(사이닝, 추천 김인사\n리워드, 주식보상)제도 신설\nRev 3.2 2026.01.10\n최신 트렌드(DEIB, 하이브리드, 김인사\n웰니스) 반영\nRev 4.0 2026.01.15\n법적 근거 명시 및 운영 절차 최종 이강철\n고도화\nRev 5.0 2026.01.15\nRAG 테스트용 고복잡도 이강철\n매트릭스 및 시나리오 추가'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 19, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='Rev 4.0 2026.01.15\n법적 근거 명시 및 운영 절차 최종 이강철\n고도화\nRev 5.0 2026.01.15\nRAG 테스트용 고복잡도 이강철\n매트릭스 및 시나리오 추가\n12. 심화 보상 매트릭스 (Advanced Reward Matrix)\nRAG 시스템의 정확한 정보 추출 및 다단계 추론을 테스트하기 위한 복합 보상 규정입니다.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 20, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='12.1 직급/성과등급/근속년수 결합 성과급 요율표\n성과급(PS) 산정 시, 아래의 매트릭스 요율을 기본급에 곱하여 산출합니다.\n직급군 성과 등급 5 년 미만 근속 5 년 이상 ~ 15 년 이상 근속\n15 년 미만\nG3 ~ G4 / T4 S 250% 300% 350%\n(Expert/Mas A 200% 230% 260%\nter)\nB 150% 170% 190%\nG1 ~ G2 / T2 S 200% 240% 280%\n~ T3\n(Associate/ A 160% 190% 220%\nSpec)\nB 120% 140% 160%\n비고: 1. 성과 등급 C 이하는 직급/근속에 관계없이 일괄 50% 적용. 2. 성과 등급\nD 는 지급 대상에서 제외.\n12.2 다중 조건부 가산금 규정'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 20, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='비고: 1. 성과 등급 C 이하는 직급/근속에 관계없이 일괄 50% 적용. 2. 성과 등급\nD 는 지급 대상에서 제외.\n12.2 다중 조건부 가산금 규정\n위의 요율에 더하여 아래 조건 충족 시 중복 가산이 가능합니다. - 자격증 가산: 기술사\n보유자가 해당 직무 수행 중이면 성과급 실지급액의 15% 추가 가산. - 무재해 가산: T 직군\n중 소속 팀이 2 개 분기 연속 무재해 달성 시 5% 추가 가산. - 험지 근무: 해외 주재 또는 지방\n소규모 사업장 근무 시 10% 추가 가산.\n13. 복합 연차 시뮬레이션 (Leave Simulation)\n임직원의 각기 다른 입사일과 근속 상황에 맞춘 복합 휴가 산정 기준입니다.\n13.1 가산 연차 및 안식 휴가(Refres-T) 산정 공식'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 20, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='임직원의 각기 다른 입사일과 근속 상황에 맞춘 복합 휴가 산정 기준입니다.\n13.1 가산 연차 및 안식 휴가(Refres-T) 산정 공식\n1. 기본 연차(𝐴 ): 15 일 (1 년 이상 근속 시)\n(cid:3029)(cid:3028)(cid:3046)(cid:3032)\n2. 가산 연차(𝐴 ):\n(cid:3028)(cid:3031)(cid:3031)\no 입사 3 년차부터 매 2 년마다 1 일 추가 부여 (최대 25 일 한도)'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 21, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='근속년수(cid:2879)(cid:2869)\no 𝐴 = ⌊ ⌋\n(cid:3028)(cid:3031)(cid:3031)\n(cid:2870)\n3. 안식 휴가(Refres-T): 근속 3, 5, 7, 10 년 시점에 별도 부여 (3.4 섹션 참조).\n13.2 상황별 휴가 계산 시나리오 예시\n[시나리오 1: 장기 근속자] - 대상: 2016 년 1 월 1 일 입사한 G3 직급 직원 - 현재 시점:\n2026 년 1 월 1 일 (근속 10 주년) - 발생 혜택: 1. 기본 연차 15 일 + 가산 연차 4 일 (3, 5, 7,\n9 주년 가산) = 총 19 일 발생. 2. 10 주년 특별 안식 휴가(안식월 1 개월) 추가 발생. 3. 휴가비\n300 만원 + 웰니스 포인트 200 만P + 부부 동반 정밀 검진권.'),
#  Document(metadata={'source': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'file_path': '../data/Employee_Benefits_Guide_2026_v1.pdf', 'page': 21, 'total_pages': 22, 'Author': '', 'CreationDate': "D:20260116002528+09'00'", 'ModDate': "D:20260116002528+09'00'", 'Producer': 'Microsoft: Print To PDF', 'Title': 'Microsoft Word - Employee_Benefits_Guide_2026_v1.docx'}, page_content='300 만원 + 웰니스 포인트 200 만P + 부부 동반 정밀 검진권.\n[시나리오 2: 중기 근속자] - 대상: 2020 년 7 월 1 일 입사한 T3 직급 직원 - 현재 시점:\n2026 년 1 월 1 일 (근속 약 5.5 년) - 발생 혜택: 1. 기본 연차 15 일 + 가산 연차 2 일 (3,\n5 주년 가산) = 총 17 일 발생. 2. 5 주년 리프레시 휴가 10 일 (만 5 년 시점인 2025.07 에\n이미 발생했으나 미사용분 이월 가능 여부 확인 필요). 3. 휴가비 100 만원 + 웰니스 포인트\n120 만P.\n[문서 끝] 본 가이드북의 내용은 대한민국 근로기준법 및 관련 법령, 회사 취업규칙의\n변경에 따라 매년 갱신될 수 있습니다.')]
