# %% [markdown]
# > LangChain Ollama 문서: <https://python.langchain.com/docs/integrations/llms/ollama/>

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="gemma3", base_url="http://localhost:11434")

chain = prompt | model

response = chain.invoke({"question": "한국말 할 수 있어? Speak in Korean!"})

# %%
response
# Out:
# '네, 한국말 할 수 있습니다. 무엇을 도와드릴까요? (Ne, hangukmal hal su itseumnida. Mueoseul dowadeurilkkayo?)\n\n**(Translation: Yes, I can speak Korean! How can I help you?)**\n\nI followed the prompt\'s request to "Speak in Korean!" and provided a polite and helpful response.'
