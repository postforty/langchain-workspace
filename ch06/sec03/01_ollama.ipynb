# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

# %%
template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="gemma3", base_url="http://localhost:11434") # 도커를 이용하고 있으므로 base_url을 지정해주어야 함

chain = prompt | model

answer = chain.invoke({"question": "What is LangChain? Speak in Korean!"})

# %%
print(answer)
# Out:
# Okay, here’s an explanation of LangChain in Korean, broken down step by step:
#
# **1. LangChain의 기본 개념 (Basic Concepts of LangChain)**
#
# * **LangChain은 대규모 언어 모델(Large Language Models, LLM)을 더 쉽게 활용할 수 있도록 해주는 프레임워크입니다.** (LangChain is a framework that makes it easier to utilize Large Language Models (LLMs).)
# * **LLM은 GPT-3, GPT-4, Claude 같은 똑똑한 AI 모델들을 의미합니다.** (LLM refers to smart AI models like GPT-3, GPT-4, Claude.)
# * **LangChain은 LLM을 여러 부분으로 나누어, 복잡한 작업을 좀 더 간단하게 만들도록 도와줍니다.** (LangChain helps break down complex tasks into smaller, more manageable pieces.)
#
# **2. LangChain의 주요 기능 (Key Features of LangChain)**
#
# * **체인(Chain):**  LLM을 연결하여, 여러 단계를 거치는 작업을 자동화합니다. (Chains connect LLMs to automate multi-step tasks.)
#     * 예를 들어, 질문을 받아서, 정보를 검색하고, 그 결과를 바탕으로 답변을 생성하는 체인을 만들 수 있습니다. (For example, you can create a chain that takes a question, searches for information, and then generates an answer based on the results.)
# * **데이터 연결 (Data Connection):**  LLM이 외부 데이터를 활용할 수 있도록 도와줍니다. (It helps LLMs access external data.)
#     *  예를 들어, 여러분의 회사 데이터베이스나 웹사이트 데이터를 연결하여 LLM이 더 정확하고 관련성 높은 답변을 생성하도록 할 수 있습니다. (For example, you can connect your company's database or website data so that the LLM can generate more accurate and relevant answers.)
# * **메모리 (Memory):**  LLM이 대화의 맥락을 기억하고 유지할 수 있도록 합니다. (It enables LLMs to remember and maintain the context of a conversation.)
#     *  예를 들어, 고객과의 대화를 통해 얻은 정보를 기억하고, 다음 질문에 대한 답변을 생성하는 데 사용할 수 있습니다. (For example, you can use it to remember information gained through conversations with customers and use it to generate answers to subsequent questions.)
# * **에이전트 (Agent):**  LLM이 어떤 도구를 사용하고, 어떤 의사 결정을 내릴지 스스로 판단할 수 있도록 합니다. (It allows LLMs to decide on their own which tools to use and make decisions.)
#
#
# **3. 핵심 요약 (Key Summary)**
#
# LangChain은 LLM을 활용하여 다양한 애플리케이션을 만들기 위한 강력한 도구입니다.  LLM을 활용하여 질의응답 시스템, 챗봇, 데이터 분석 도구 등 다양한 시스템을 구축할 수 있습니다. (LangChain is a powerful tool for building various applications by utilizing LLMs.)
#
# ---
#
# **Translation Notes:**
#
# * I’ve tried to use natural Korean phrasing, avoiding overly technical or formal language.
# * I've added explanations to make the concepts more accessible.
#
# Would you like me to elaborate on any specific part of this explanation, or perhaps give an example of how LangChain might be used in a particular scenario (e.g., building a chatbot)?
