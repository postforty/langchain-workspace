# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader("../data/2026_수능특강_문학_slice.pdf")
docs = loader.load()

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
from langchain_core.prompts import ChatPromptTemplate

propmt = ChatPromptTemplate.from_messages(
    [
        ("system", """당신은 제공된 텍스트에서 의미 있고 맥락적으로 관련된 질문을 생성하도록 설계된 고급 질문 생성기입니다.
주어진 텍스트를 사용하여 한국어로 사고를 자극하거나 이해력 기반의 질문을 생성하세요.
답변은 포함하지 마세요.
\n\n     
{context}"""),
        ("human", "{input}")
    ]
)

# %%
chain = propmt | model

# %%
pdf_context = ""
for doc in docs:
    pdf_context += doc.page_content

# %%
pdf_context
# Out:
# '1 Úᬒ‷wⲒ⸺\n(1) 시적 표현의 개념\n• 시의 주제나 화자의 정서를 형상화하는 데 기여하는 일체의 언어적 표현을 가리킴.\n• 비유, 상징, 역설, 반어, 대구, 반복, 설의, 영탄, 도치, 열거, 점층, 우의, 풍자, 병렬 등\n의 표현 기법이 있음.\n(2) 시적 표현의 여러 가지 효과\n•음악적인 리듬이 느껴지게 함.\n•시어의 함축성을 높여 의미를 풍부하게 함.\n•어떤 대상을 감각적으로 연상하게 함.\n•상식적인 생각을 뒤집거나 깨뜨림으로써 지적 충격을 줌.\n•재미를 느끼고 웃게 하거나 반대로 슬픈 감정을 환기하게 함.\n•일상적인 표현에 변화를 가하여 말의 묘미를 느끼게 함.\n•화자의 사고나 감정, 상황 등을 강조하거나 부각함.\n 형상화\n정서나 교훈, 삶의 이치 등과 같\n이 분명한 형체로 나타나 있지 \n않은 것을 다양한 방법이나 매체\n를 통해 구체적이고 실감 나게 \n그려 내는 것을 뜻한다. 문학에\n서는 마음이나 윤리적 덕목과 같\n은 추상적인 대상도 구체적인 형\n상으로 드러난다.\n2 Úᬒᾎw⹋ᬓ\n(1) 시의 형식의 개념과 특성\n• 율격, 시행, 연 등의 요소가 시의 주제나 화자의 정서를 표현하면서 이루는 전체적인 형\n태나 구조를 가리킴. 크게 고정된 형식과 자유로운 형식으로 구별됨.\n•시의 형식은 문화적으로 형성된 시 고유의 체계와 관습에 기반을 두고 있음.    \n(2) 시의 형식의 여러 층위\n•갈래: 민요, 시조, 가사, 자유시 등\n•담화 양식: 독백, 대화, 편지, 전화 통화의 형식 등\n•구조: 기승전결, 수미상관, 선경후정, 대칭, 아이러니(반어) 등\n•진술 형태: 정형시, 자유시, 산문시, 이야기시, 극시 등\n•형태: 시행 및 연의 배열 등\n•청자의 존재: 독백, 대화 등   \n•시상 전개: 원경- 근경, 외부 풍경-내면세계, 과거-현재-미래 등\n 표현과 형식의 관계\n시적 표현이라는 말의 의미는 그 \n폭이 매우 넓어서 형식의 의미를 \n포괄하는 경우가 많다. 그러므로 \n표현과 형식을 별도의 개념으로 \n인식하기보다는 형식을 표현의 \n한 부분으로 이해하는 것이 바람\n직하다.\n 독백과 대화\n독백은 화자가 자신을 청자로 삼\n아 하는 말이고, 대화는 청자를 \n향해서 하는 말이다. 따라서 상대\n방을 상정하고 하는 질문, 명령, \n부탁, 위로, 격려 등의 말은 형식\n적으로 대화에 해당한다. ‘~입니\n다’ 등의 높임말도 자신에게 하\n는 말이 아니라는 점에서 표면적\n으로는 대화 형식에 해당한다.\nᬒᾎwⲒ⸺Բw⹋ᬓ\n1\n008  EBS 수능특강 국어영역 문학'

# %%
res = chain.invoke({
    "context": pdf_context, "input": "4지선다 3문항을 만들어 주세요."
})

# %%
print(res.content)
# Out:
# ## 시적 표현과 형식에 대한 문제
#
# **1. 다음 중 시적 표현의 효과로 보기 어려운 것은?**
#
# ① 음악적인 리듬감을 부여한다.
# ② 시어의 함축성을 높여 의미를 풍부하게 한다.
# ③ 상식적인 생각을 뒤집어 지적 충격을 준다.
# ④ 시의 주제를 직접적으로 설명하여 이해를 돕는다.
#
# **2. '형상화'의 의미를 가장 잘 나타내는 것은?**
#
# ① 추상적인 대상을 구체적인 형상으로 드러내는 것
# ② 시의 주제나 화자의 정서를 직접적으로 묘사하는 것
# ③ 시어의 음악적인 리듬감을 살리는 것
# ④ 시의 형식적인 구조를 다양하게 변형하는 것
#
# **3. 시의 형식에 대한 설명으로 가장 적절한 것은?**
#
# ① 율격, 시행, 연 등의 요소로 이루어진 시의 고정된 틀만을 의미한다.
# ② 시의 주제나 화자의 정서를 표현하는 전체적인 형태나 구조를 가리키며, 고정된 형식과 자유로운 형식으로 나뉜다.
# ③ 시적 표현의 한 종류로, 반드시 일정한 규칙과 관습을 따라야 한다.
# ④ 시의 내용과 완전히 분리되어 독립적으로 존재하는 요소이다.
