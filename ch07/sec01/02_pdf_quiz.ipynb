# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader("../data/2026_수능특강_문학_slice.pdf")
docs = loader.load()

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """당신은 제공된 텍스트에서 의미 있고 맥락적으로 관련된 질문을 생성하도록 설계된 고급 질문 생성기입니다.
            주어진 텍스트를 사용하여 한국어로 사고를 자극하거나 이해력 기반의 질문을 생성하세요.
            답변은 포함하지 마세요.
            
            {context}"""
        ),
        ("human", "{input}")
    ]
)

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-3.1-flash-lite")

# %%
chain = prompt | model

# %%
response = chain.invoke(
    {"context": docs, "input": "4지선다 3문항을 만들어 주세요."}
)

# %%
print(response.content[0]["text"])
# Out:
# 제시된 텍스트를 바탕으로 구성한 4지선다형 질문 3문항입니다.
#
# **1. 시적 표현의 효과에 대한 설명으로 적절하지 않은 것은 무엇입니까?**
# ① 시어의 함축성을 높여 작품의 의미를 풍부하게 한다.
# ② 대상을 감각적으로 연상하게 하여 실감 나게 표현한다.
# ③ 고정된 형식만을 사용하여 독자에게 안정적인 리듬감을 준다.
# ④ 일상적인 표현에 변화를 주어 말의 묘미를 느끼게 한다.
#
# **2. ‘형상화’의 개념을 가장 잘 설명한 것은 무엇입니까?**
# ① 추상적인 대상이나 정서를 구체적인 모습으로 드러내는 것
# ② 시적 허용을 통해 문법에 맞지 않는 표현을 허용하는 것
# ③ 화자의 감정을 최대한 절제하여 객관적인 태도를 유지하는 것
# ④ 독자에게 교훈을 직접적으로 제시하여 주제를 명확히 하는 것
#
# **3. ‘시의 형식’과 ‘표현’의 관계에 대한 설명으로 가장 적절한 것은 무엇입니까?**
# ① 표현과 형식은 서로 독립된 개념으로 분류하여 분석해야 한다.
# ② 형식은 표현의 한 부분으로 포함하여 이해하는 것이 바람직하다.
# ③ 고정된 형식만이 시적 표현의 효과를 극대화할 수 있다.
# ④ 대화나 독백과 같은 담화 양식은 시의 표현 기법에 포함되지 않는다.
