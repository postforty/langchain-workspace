# %% [markdown]
# ### Ollama 모델
#
# #### gemma3

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="gemma3:4b",
    temperature=0,
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Korean. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content="That translates to:\n\n**프로그래밍을 정말 좋아해요.** (peu-ro-ge-re-mi-neul jeongmal jo-a-hae-yo)\n\nHere's a breakdown:\n\n*   **프로그래밍** (peu-ro-ge-re-mi-neun) - programming\n*   **을** (eul) - object marker (indicates what you love)\n*   **정말** (jeongmal) - really, truly\n*   **좋아해요** (jo-a-hae-yo) - I love (formal/polite)\n\nWould you like me to offer another translation, perhaps a more casual one?", additional_kwargs={}, response_metadata={'model': 'gemma3:4b', 'created_at': '2026-05-23T07:40:17.740438447Z', 'done': True, 'done_reason': 'stop', 'total_duration': 93564765890, 'load_duration': 26449405017, 'prompt_eval_count': 34, 'prompt_eval_duration': 1883852795, 'eval_count': 148, 'eval_duration': 64703080430, 'logprobs': None, 'model_name': 'gemma3:4b', 'model_provider': 'ollama'}, id='lc_run--019e53c5-ac38-75f3-b849-282621a898db-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 148, 'total_tokens': 182})

# %% [markdown]
# ---

# %% [markdown]
# #### BGE-M3 임베딩 모델
#
# 한국어 임베딩 성능 준수함.

# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="bge-m3:latest",
)

# %%
# Create a vector store with a sample text
from langchain_core.vectorstores import InMemoryVectorStore

text = "LangChain is the framework for building context-aware reasoning applications"

vectorstore = InMemoryVectorStore.from_texts(
    [text],
    embedding=embeddings,
)

# Use the vectorstore as a retriever
retriever = vectorstore.as_retriever()

# Retrieve the most similar text
retrieved_documents = retriever.invoke("What is LangChain?")

# Show the retrieved document's content
print(retrieved_documents[0].page_content)
# Out:
# LangChain is the framework for building context-aware reasoning applications

# %%
single_vector = embeddings.embed_query(text)
print(str(single_vector)[:100])  # Show the first 100 characters of the vector
# Out:
# [-0.016262822, -0.011644539, 0.0041515245, -0.011454773, -0.017770415, -0.051896892, 0.019081196, 0.
