# %%
# uv add langchain-ollama

from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="gemma3:4b")

chain = prompt | model

chain.invoke({"question": "What is LangChain? Speak in Korean"})
# Out:
# "Okay, here's a Korean explanation of LangChain, broken down step-by-step, aiming for clarity:\n\n**LangChain이란 무엇일까요? (What is LangChain?)**\n\n1. **핵심 아이디어 (Core Idea):** LangChain은 대규모 언어 모델 (Large Language Models, LLM) – 즉, ChatGPT와 같은 똑똑한 AI – 를 다른 도구들과 연결하여 더 강력하고 유연하게 사용할 수 있도록 도와주는 프레임워크입니다. (LangChain is a framework that helps connect Large Language Models (LLMs) – like ChatGPT – with other tools to make them more powerful and flexible.)\n\n2. **LLM과의 연결 (Connecting with LLMs):**  LLM 자체는 훌륭하지만, 종종 정보를 찾거나, 외부 데이터에 접근하거나, 복잡한 작업을 수행하기에는 한계가 있습니다. LangChain은 LLM이 이러한 작업을 수행할 수 있도록 도와주는 '연결자' 역할을 합니다. (LLMs themselves are great, but often they have limitations in finding information, accessing external data, or performing complex tasks. LangChain acts as a ‘connector’ that helps LLMs do these things.)\n\n3. **다양한 도구 (Various Tools):** LangChain은 다양한 도구들을 LLM과 연결할 수 있도록 해줍니다. 예를 들어:\n   * **검색 엔진 (Search Engines):** Google 검색을 사용하여 웹에서 정보를 찾습니다. (Searching search engines like Google to find information online.)\n   * **데이터베이스 (Databases):**  데이터베이스에서 정보를 가져와 LLM에게 제공합니다. (Retrieving information from databases to provide to LLMs.)\n   * **API (APIs):** 다양한 API를 사용하여 LLM이 외부 서비스와 상호 작용하도록 합니다. (Allowing LLMs to interact with external services through APIs.)\n\n4. **체인 (Chains):**  LangChain의 핵심은 '체인'입니다.  체인은 여러 도구와 LLM을 순서대로 연결하여 복잡한 작업을 수행하는 일련의 단계를 만듭니다.  예를 들어, 질문을 받고, 웹에서 정보를 검색하고, 그 정보를 바탕으로 답변을 생성하는 체인을 만들 수 있습니다. (The core of LangChain is ‘chains.’ A chain connects multiple tools and LLMs in a sequence to perform complex tasks.  You can create a chain, for example, that takes a question, searches the web for information, and generates an answer based on that information.)\n\n5. **개발을 더 쉽게 (Making Development Easier):** LangChain은 복잡한 LLM 애플리케이션 개발을 훨씬 더 쉽고 효율적으로 만들어 줍니다.  다양한 예제와 도구를 제공하여 개발자가 LLM의 잠재력을 최대한 활용하도록 돕습니다. (LangChain makes developing complex LLM applications much easier and more efficient. It provides a variety of examples and tools to help developers fully utilize the potential of LLMs.)\n\n\n**Translation Breakdown:**\n\n*   **핵심 아이디어 (Hyeoksim Aidieo):** Core Idea\n*   **대규모 언어 모델 (Daegimo Unyeo Model):** Large Language Model\n*   **연결자 (Yeongyeolja):** Connector\n*   **체인 (Chein):** Chain\n*   **API (API):** API\n\n---\n\n**Would you like me to:**\n\n*   Explain a specific aspect of LangChain in more detail?\n*   Provide an example of a LangChain chain?\n*   Translate any part of this explanation into English?"

# %% [markdown]
# ---

# %%
# uv add ollama

from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="gemma3:4b",
    temperature=0,
    # other params...
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Korean. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content="That translates to:\n\n**프로그래밍을 정말 좋아해요.** (peu-ro-ge-re-mi-neul jeongmal jo-a-hae-yo)\n\nHere's a breakdown:\n\n*   **프로그래밍** (peu-ro-ge-re-mi-neun) - programming\n*   **을** (eul) - object marker (indicates what you love)\n*   **정말** (jeongmal) - really, truly\n*   **좋아해요** (jo-a-hae-yo) - I love (formal/polite)\n\nWould you like me to offer another translation, perhaps a more casual one?", additional_kwargs={}, response_metadata={'model': 'gemma3:4b', 'created_at': '2026-01-25T06:52:04.335133661Z', 'done': True, 'done_reason': 'stop', 'total_duration': 94579507875, 'load_duration': 32442282361, 'prompt_eval_count': 34, 'prompt_eval_duration': 1899938373, 'eval_count': 148, 'eval_duration': 59681877416, 'logprobs': None, 'model_name': 'gemma3:4b', 'model_provider': 'ollama'}, id='lc_run--019bf3eb-19fa-7542-ac71-8e81d5703765-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 148, 'total_tokens': 182})

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="translategemma:4b",
    temperature=0,
    # other params...
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Korean. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content='저는 프로그래밍을 정말 좋아해요.\n', additional_kwargs={}, response_metadata={'model': 'translategemma:4b', 'created_at': '2026-01-25T07:01:38.69356095Z', 'done': True, 'done_reason': 'stop', 'total_duration': 38854664069, 'load_duration': 31998088431, 'prompt_eval_count': 34, 'prompt_eval_duration': 1896982073, 'eval_count': 11, 'eval_duration': 4640107360, 'logprobs': None, 'model_name': 'translategemma:4b', 'model_provider': 'ollama'}, id='lc_run--019bf3f4-b73c-7d30-bc39-c3244ff35fe2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 11, 'total_tokens': 45})

# %% [markdown]
# ---

# %%
# uv add langchain-ollama

from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="bge-m3:latest",
)

# %%
text = "김일남"

# %%
single_vector = embeddings.embed_query(text)
print(str(single_vector)[:100])  # Show the first 100 characters of the vector
# Out:
# [-0.011843671, 0.04405691, -0.019254446, -0.01907072, -0.026237255, 0.03619279, -0.0006774108, -0.01
