# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    # model="gemma4:e2b",
    model="gemma3:1b",
    temperature=0,
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Korean. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content='저는 프로그래밍을 사랑합니다. (Jeoneun proegryam-eul saranghamnida.)\n\nThis translates to: “I love programming.”  It’s a polite and natural way to say it in Korean. \n\nDo you want me to translate anything else?', additional_kwargs={}, response_metadata={'model': 'gemma3:1b', 'created_at': '2026-04-04T08:13:29.082575852Z', 'done': True, 'done_reason': 'stop', 'total_duration': 10521898010, 'load_duration': 944129691, 'prompt_eval_count': 34, 'prompt_eval_duration': 409709558, 'eval_count': 62, 'eval_duration': 9063370271, 'logprobs': None, 'model_name': 'gemma3:1b', 'model_provider': 'ollama'}, id='lc_run--019d578d-b75d-7123-b790-bd824062160c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 62, 'total_tokens': 96})

# %% [markdown]
# ---

# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="bge-m3:latest",
)

# %%
# Create a vector store with a sample text
from langchain_core.vectorstores import InMemoryVectorStore

text = "LangChain is the framework for building context-aware reasoning applications"

vectorstore = InMemoryVectorStore.from_texts(
    [text],
    embedding=embeddings,
)

# Use the vectorstore as a retriever
retriever = vectorstore.as_retriever()

# Retrieve the most similar text
retrieved_documents = retriever.invoke("What is LangChain?")

# Show the retrieved document's content
print(retrieved_documents[0].page_content)
# Out:
# LangChain is the framework for building context-aware reasoning applications

# %%
single_vector = embeddings.embed_query(text)
print(str(single_vector)[:100])  # Show the first 100 characters of the vector
# Out:
# [-0.016262822, -0.011644539, 0.0041515245, -0.011454773, -0.017770415, -0.051896892, 0.019081196, 0.
