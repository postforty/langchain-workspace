# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents.middleware import before_agent
from langchain.messages import AIMessage

@before_agent(can_jump_to = ["end"])
def validate_agent(state, runtime):
    human_message = state["messages"][-1]

    if "금지어" in human_message.content:
        print("금지어 감지")
        return {
            "messages": [AIMessage(content="현재 금지어가 포함되어 있습니다.")],
            "jump_to": "end"
        }
    return None

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="google_genai:gemini-3.1-flash-lite",
    middleware=[validate_agent],
)

# %%
agent.invoke(
    {"messages": [{"role": "user", "content": "이런 금지어 같은 경우를 봤나!"}]},
)
# Out:
# 금지어 감지
# {'messages': [HumanMessage(content='이런 금지어 같은 경우를 봤나!', additional_kwargs={}, response_metadata={}, id='973f0d3c-2af8-486d-b090-beb0bb46e90a'),
#   AIMessage(content='현재 금지어가 포함되어 있습니다.', additional_kwargs={}, response_metadata={}, id='b2c667ff-7aa9-4251-9489-5d706a7b8fbf', tool_calls=[], invalid_tool_calls=[])]}

# %%
agent.invoke(
    {"messages": [{"role": "user", "content": "이런 훌륭한 사례 같은 경우를 봤나!"}]},
)
# Out:
# {'messages': [HumanMessage(content='이런 훌륭한 사례 같은 경우를 봤나!', additional_kwargs={}, response_metadata={}, id='7a5bb1e0-ad68-4c08-a774-e6b330c25d42'),
#   AIMessage(content=[{'type': 'text', 'text': "정말 감탄이 절로 나오는 순간이군요! 어떤 사례를 보셨길래 그렇게 크게 감동하셨나요?\n\n상대방의 뛰어난 역량, 예상치 못한 문제 해결 능력, 혹은 마음을 울리는 따뜻한 배려 등 **'훌륭하다'고 느낀 포인트**를 조금 더 자세히 들려주세요. 함께 공감하고 나누면 그 가치가 훨씬 더 커질 것 같습니다!", 'extras': {'signature': 'EjQKMgEMOdbHn1pkMC39SmzeNHBb9TZ1AC/LpBzkoXZj6dBUZk2C2hTUsorSYiRZuU+C+SRI'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e7cd8-f547-75c3-becc-12a769ff917a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 92, 'total_tokens': 106, 'input_token_details': {'cache_read': 0}})]}
