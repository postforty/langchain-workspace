# %%
import os
from dotenv import load_dotenv
load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.1, # 창의성 (0.0~2.0)
    google_api_key=gemini_api_key
)

# %%
response = llm.invoke("대한민국의 수도는?")

# %%
response.content
# Out:
# '대한민국의 수도는 **서울**입니다.'

# %%
response.response_metadata
# Out:
# {'prompt_feedback': {'block_reason': 0, 'safety_ratings': []},
#  'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'safety_ratings': []}

# %%
response.usage_metadata
# Out:
# {'input_tokens': 7,
#  'output_tokens': 184,
#  'total_tokens': 191,
#  'input_token_details': {'cache_read': 0},
#  'output_token_details': {'reasoning': 174}}

# %%
response = llm.stream("Langchain에 대해 쉽게 설명해줘.")

# %%
response
# Out:
# <generator object BaseChatModel.stream at 0x0000019BCBFD37F0>

# %%
next(response)
# Out:
# AIMessageChunk(content='Langchain은 쉽게 말해 **"똑똑한 인공지능(LLM)을 활용해서 더 똑똑하고 유용한 앱을 만들 수 있게 도와주는 만능 도우미"** 라고 생각하시면 됩니다.\n\n조', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--f74cf6ee-11a8-425c-88f8-24b81e148da2', usage_metadata={'input_tokens': 10, 'output_tokens': 1286, 'total_tokens': 1296, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1237}})

# %%
for token in response:
    print(token.content, end="", flush=True)
# Out:
# Langchain은 한마디로 **"똑똑한 인공지능(LLM)이 더 많은 일을 할 수 있도록 도와주는 도구 모음"** 이라고 생각하시면 됩니다.
#
# 조금 더 쉽게 비유해볼게요.
#
# ---
#
# ### **Langchain, LLM의 슈퍼파워 비서!**
#
# 당신에게 **아주 똑똑한 비서(LLM)**가 한 명 있다고 상상해보세요. 이 비서는 글을 정말 잘 쓰고, 요약도 잘하고, 아이디어도 기가 막히게 내놓습니다.
#
# 하지만 이 비서에게는 몇 가지 한계가 있습니다.
#
# 1.  **최신 정보를 몰라요:** "오늘 주식 시장이 어때?"라고 물으면, 자기가 학습했던 과거 데이터만 가지고 대답합니다. 실시간 정보를 검색할 줄 몰라요.
# 2.  **개인적인 정보를 몰라요:** "우리 회사 지난달 매출 보고서 좀 요약해줘"라고 하면, 회사 내부 데이터에 접근할 수 없으니 모른다고 합니다.
# 3.  **행동을 할 수 없어요:** "이메일 초안 작성해서 보내줘"라고 하면, 초안은 써주지만 실제로 이메일을 보낼 수는 없습니다.
# 4.  **기억력이 짧아요:** "지난번에 우리가 얘기했던 그 프로젝트 말이야..."라고 하면, 이전 대화를 기억하지 못하고 다시 설명해줘야 합니다.
# 5.  **복잡한 일을 혼자서 못해요:** "인터넷에서 최신 정보를 찾아서, 우리 회사 문서랑 비교한 다음, 보고서 초안을 써줘" 같은 여러 단계를 거쳐야 하는 일은 어려워합니다.
#
# ---
#
# **여기서 Langchain이 등장합니다!**
#
# Langchain은 이 똑똑한 비서(LLM)에게 **"도구"와 "매뉴얼", 그리고 "기억력"**을 제공해주는 역할을 합니다.
#
# *   **도구 (Tools):**
#     *   "인터넷 검색 엔진" (웹 검색 기능)
#     *   "회사 데이터베이스 접근 권한" (내부 문서 검색 기능)
#     *   "이메일 발송 기능" (API 연동)
#     *   "계산기" (수학 계산 기능)
#     *   ... 등등, 비서가 직접 할 수 없었던 다양한 외부 기능을 연결해줍니다.
#
# *   **매뉴얼/지시사항 (Chains & Agents):**
#     *   "먼저 인터넷에서 최신 정보를 찾아봐."
#     *   "그 다음, 우리 회사 문서에서 관련 내용을 찾아봐."
#     *   "마지막으로, 이메일 초안을 작성해서 나한테 보여줘."
#     *   이런 식으로 여러 단계를 거쳐야 하는 복잡한 작업을 비서가 순서대로 처리할 수 있도록 **작업 흐름(Chain)**을 만들어줍니다.
#     *   심지어 비서가 스스로 "어떤 도구를 언제 사용해야 할지" 판단하게 하는 **에이전트(Agent)** 기능도 제공합니다.
#
# *   **기억력 (Memory):**
#     *   "우리가 지난번에 얘기했던 내용을 기억해줘."
#     *   이전 대화 내용을 저장하고 있다가, 비서가 다음 대화에서 그 내용을 참고할 수 있도록 해줍니다.
#
# ---
#
# ### **결론적으로 Langchain은:**
#
# LLM(똑똑한 비서)이 단순히 글만 쓰는 것을 넘어,
#
# 1.  **외부 정보를 찾아보고 (인터넷 검색, 데이터베이스 접근)**
# 2.  **실제 행동을 수행하고 (이메일 발송, 다른 프로그램 연동)**
# 3.  **이전 대화를 기억하고 (대화 이력 관리)**
# 4.  **여러 단계를 거쳐 복잡한 작업을 처리할 수 있도록 (작업 흐름 관리)**
#
# 만들어주는 **프레임워크(Framework)**입니다.
#
# Langchain 덕분에 우리는 LLM을 활용해서 훨씬 더 유용하고 강력한 인공지능 서비스를 만들 수 있게 된 것이죠! 마치 똑똑한 비서에게 슈퍼파워를 장착해주는 것과 같습니다.
