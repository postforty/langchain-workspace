# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.0
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
response = model.invoke(prompt)

# %%
print(response.content)
# Out:
# LangChain 개발자인 나는 새로운 에이전트 구축에 몰두했다. 먼저 `PromptTemplate`으로 에이전트의 핵심 성격을 정의하고, `Memory`를 심어 과거 대화를 기억하게 했다. 여러 도구들을 정교하게 엮어 복잡한 `Chain`을 완성하니, 똑똑한 에이전트가 탄생했다.
#
# 어느 날, 사무실 네트워크가 갑자기 마비되어 모두가 혼란에 빠졌다. 에이전트는 침착하게 "네트워크 진단 도구를 실행하고, 문제 해결 가이드를 찾아보겠습니다"라고 말하며, 스스로 진단 후 복구 절차를 안내했다. 예상치 못한 네트워크 장애였지만, 에이전트는 완벽하게 문제를 해결했다.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=2.0
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
response = model.invoke(prompt)

# %%
print(response.content)
# Out:
# 랑체인 개발자로서 난 새로운 에이전트를 만들었다. 'PromptTemplate'으로 성격을 부여하고, 복잡한 사고 과정을 'Chain'으로 엮었다. 대화 흐름을 잊지 않도록 중요한 'Memory' 저장고도 달아주었다. 그렇게 에이전트가 완성되었다.
#
# 어느 날, 전력망 불안정으로 예기치 않게 주요 시스템이 마비될 위기에 처했다. 매뉴얼에 없는 비상 상황! 에이전트는 과거 학습 데이터와 'Memory'를 종합하고, 놀랍게도 공장의 유휴 태양광 패널을 가동해 보조 전력으로 전환하는 창의적인 해결책을 찾아내며 위기를 극복했다. 시스템은 안정적으로 가동되었다.

# %% [markdown]
# ---

# %% [markdown]
# 스트리밍 출력

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
)

# %%
response = model.stream("랭체인에 대해 아주 쉽게 설명해줘.")

# %%
response
# Out:
# <generator object BaseChatModel.stream at 0x000002610FB1F6A0>

# %%
next(response)
# Out:
# AIMessageChunk(content='랭체인,', additional_kwargs={}, response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ccc86-96d3-73b3-883f-6159294aad01', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 2233, 'total_tokens': 2245, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 2229}}, tool_call_chunks=[])

# %%
next(response)
# Out:
# AIMessageChunk(content=" 이거 진짜 쉽게 설명해드릴게요!\n\n---\n\n**랭체인은 쉽게 말해 '인공지능(LLM)을 활용해서 더 복잡하고 유용한 프로그램을 만들 수 있게 도와주는 만능 도구 상자", additional_kwargs={}, response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ccc86-96d3-73b3-883f-6159294aad01', tool_calls=[], invalid_tool_calls=[], usage_metadata={'total_tokens': 49, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}, 'input_tokens': 0, 'output_tokens': 49}, tool_call_chunks=[])

# %%
next(response).content
# Out:
# "'라고 생각하면 돼요.**\n\n이게 무슨 말이냐고요? 요리사에 비유해서 설명해볼게요.\n\n---\n\n### 🍳 요리사에 비유한 랭체인\n\n1.  **똑똑한 셰"

# %%
next(response).content
# Out:
# '프 보조 (LLM):**\n    *   챗GPT 같은 인공지능은 엄청 똑똑한 셰프 보조예요. 재료를 보고 훌륭한 레시피를 제안하거나, 맛있'

# %%
next(response).content
# Out:
# '게 요리하는 법을 설명해줄 수 있죠.\n    *   하지만 냉장고를 열어 직접 재료를 꺼내거나, 오븐을 조작하거나, 다른 주방 도구를 사용해서 복잡한 작업을 하'

# %%
for token in response:
    print(token.content, end="", flush=True)
# Out:
# 지는 못해요. (즉, 자기가 학습한 데이터 안에서만 대답하고, 실시간 인터넷 검색이나 계산 같은 건 못한다는 뜻!)
#
# 2.  **주방의 만능 도구 (랭체인):**
#     *   랭체인은 이 셰프 보조(LLM)가 **냉장고(내 문서, 데이터베이스), 인터넷(실시간 정보), 저울(계산기), 칼(데이터 가공 도구) 같은 다양한 주방 도구들을 자유자재로 사용할 수 있게 연결해주는 역할**을 해요.
#     *   즉, 랭체인이 있으면 셰프 보조(LLM)가 직접 재료를 찾고, 가공하고, 다른 기계들과 협력해서 하나의 완벽한 요리를 만들어내는 거죠!
#
# ---
#
# ### 🛠️ 그래서 랭체인으로 뭘 할 수 있나요?
#
# 랭체인 덕분에 인공지능(LLM)은 다음과 같은 일들을 할 수 있게 됩니다.
#
# 1.  **외부 정보 연결:** 내 회사 문서, 이메일, 데이터베이스, 심지어 실시간 인터넷 검색 결과까지 인공지능이 활용할 수 있게 해줘요. (냉장고를 열어 재료를 꺼내는 것처럼!)
# 2.  **도구 사용:** 계산기, 달력, 지도 같은 다른 프로그램이나 API를 인공지능이 직접 사용하게 만들 수 있어요. (저울이나 오븐을 조작하는 것처럼!)
# 3.  **기억력 부여:** 이전에 나눴던 대화를 기억해서 더 자연스럽고 연속적인 대화를 이어나갈 수 있게 해줘요. (이전 요리 과정을 기억하는 것처럼!)
# 4.  **여러 단계 연결 (Chain):** '이 정보를 검색하고 -> 그 결과를 요약한 다음 -> 내 문서와 비교해서 -> 최종 답변을 생성해줘' 같이 여러 작업을 순서대로 처리하게 만들 수 있어요. (복잡한 레시피의 여러 단계를 따라서 요리하는 것처럼!)
#
# ---
#
# ### 🚀 왜 유용한가요?
#
# 결국, 랭체인 덕분에 우리는 단순한 챗봇을 넘어,
#
# *   **'우리 회사 데이터에 특화된 비서 AI'**
# *   **'인터넷 검색과 계산까지 완벽하게 수행하는 AI'**
# *   **'복잡한 업무 프로세스를 자동화하는 AI'**
#
# 등 훨씬 더 강력하고 유용한 인공지능 애플리케이션을 만들 수 있게 되는 거예요.
#
# ---
#
# **한마디로, 랭체인은 똑똑한 인공지능(LLM)을 진짜 '일 잘하는 만능 비서'로 만들어주는 마법 같은 도구라고 할 수 있습니다!**
