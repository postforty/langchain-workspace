# %%
import os
from dotenv import load_dotenv
load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash",
                            google_api_key=gemini_api_key)
result = llm.invoke("Sing a ballad of LangChain in Korean.")

# %%
print(result.content)
# Out:
# (잔잔하고 감성적인 발라드 풍으로, 느리고 서정적으로, 각 구절의 끝을 살짝 늘어뜨리며 부르면 좋습니다. 마치 오래된 이야기를 들려주듯, 진심을 담아 노래해주세요.)
#
# (Verse 1)
# 옛날 옛적에, 코딩의 바다 깊숙한 곳에
# 거대한 언어 모델, 홀로 빛났네
# 지혜는 깊었으나, 세상과 맞닿을 길을 찾았네
# 수많은 지식 속, 갇혀 헤매었네
#
# (Chorus)
# 오, 랭체인, 너는 다리이자 길
# 생각의 흐름을, 자유롭게 잇네
# 미지의 세계를, 탐험하는 용기
# 개발자의 꿈을, 현실로 만들었네
#
# (Verse 2)
# 어느 날, 한 줄기 빛이 스며들어
# 랭체인이라는 이름으로, 새로운 질서가
# 거대한 모델의 지능을 엮어내어
# 복잡한 작업들을, 단순케 했네
#
# (Chorus)
# 오, 랭체인, 너는 다리이자 길
# 생각의 흐름을, 자유롭게 잇네
# 미지의 세계를, 탐험하는 용기
# 개발자의 꿈을, 현실로 만들었네
#
# (Verse 3)
# 때로는 도구를 손에 쥐어주고
# 웹의 바다를 헤매게 하였네
# 때로는 에이전트 되어, 스스로 판단케 해
# 목표 향해 나아가게 이끌었네
#
# (Verse 4)
# 기억의 창고를 열어, 지난 대화를 되새기고
# 프롬프트의 마법으로, 지혜를 길어 올리네
# 외부 데이터와 지식을, 엮어내어
# 더욱 깊은 통찰을, 세상에 전하네
#
# (Bridge)
# 단순한 코드가 아니었네, 그것은 예술
# 인간과 기계의 경계를, 허물어뜨리네
# 새로운 창조의 문을, 활짝 열어주며
# 무한한 가능성을, 우리에게 선사하네
#
# (Chorus)
# 오, 랭체인, 너는 다리이자 길
# 생각의 흐름을, 자유롭게 잇네
# 미지의 세계를, 탐험하는 용기
# 개발자의 꿈을, 현실로 만들었네
#
# (Outro)
# 오, 랭체인, 그 이름 영원하리
# 코딩의 별이 되어, 길을 밝히리
# 미래의 서사를, 함께 써 내려가자
# 랭체인과 함께, 새로운 시대로!

# %%
from langchain_core.messages import HumanMessage

message_url = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "Describe the image at the URL. Speak in Korean!",
        },
        {"type": "image_url", "image_url": "https://picsum.photos/seed/picsum/200/300"},
    ]
)
result_url = llm.invoke([message_url])
print(f"Response for URL image: {result_url.content}")
# Out:
# Response for URL image: 이 이미지는 일출 또는 일몰 시간의 설산 풍경을 담고 있습니다.
#
# 오른쪽에는 눈으로 덮인 뾰족한 산봉우리가 우뚝 솟아 있으며, 일부는 따뜻한 빛을 받고 있습니다. 전경과 중경에는 부드러운 곡선을 이루는 눈 덮인 언덕 또는 눈밭이 어두운 파란색과 보라색을 띠며 그림자 속에 있는 듯한 느낌을 줍니다.
#
# 하늘은 부드러운 분홍색, 주황색, 그리고 연보라색 구름으로 아름답게 물들어 있어 새벽이나 해 질 녘의 고요하고 웅장한 분위기를 자아냅니다. 전반적으로 차분하고 평화로우면서도 웅장한 자연의 모습을 보여주는 사진입니다.

# %%
llm.invoke([HumanMessage(content="내 이름은 김일남이야.")])
# Out:
# AIMessage(content='네, 알겠습니다. 김일남 님이시군요.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--89103032-62b7-41bb-add4-bb914895c932-0', usage_metadata={'input_tokens': 9, 'output_tokens': 371, 'total_tokens': 380, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 358}})

# %%
llm.invoke([HumanMessage(content="내 이름이 뭐지?")]).content
# Out:
# '저는 이름이 없습니다. 저는 Google에서 훈련한 대규모 언어 모델입니다.'
