# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    # temperature=1.0,  # Gemini 3.0+ defaults to 1.0
    # max_tokens=None,
    # timeout=None,
    # max_retries=2,
    # other params...
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Korean. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = model.invoke(messages)
ai_msg
# Out:
# AIMessage(content=[{'type': 'text', 'text': '저는 프로그래밍을 사랑해요.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ccc62-d766-7732-b21f-e46575630aff-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 346, 'total_tokens': 367, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 338}})

# %% [markdown]
# 멀티 모달 테스트

# %%
from langchain.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

message = HumanMessage(
    content=[
        {"type": "text", "text": "Describe the image at the URL. 한국어로 답하시오."},
        {
            "type": "image",
            "url": "https://picsum.photos/seed/picsum/200/300",
        },
    ]
)
response = model.invoke([message])

# %%
response.text
# Out:
# '이 이미지는 아름다운 설산 풍경을 보여줍니다.\n\n사진의 하단은 부드럽게 물결치는 듯한 어두운 푸른색의 설원으로 이루어져 있습니다. 오른쪽에는 눈으로 덮인 뾰족한 산봉우리가 솟아 있으며, 일부가 빛을 받아 밝게 빛나고 있습니다.\n\n하늘은 구름으로 가득하며, 일출 또는 일몰의 빛을 받아 분홍색, 주황색, 보라색 등 따뜻하고 부드러운 색조로 물들어 있습니다.\n\n전반적으로 고요하고 웅장한 분위기를 자아내는 풍경 사진입니다.'
