# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

# %%
messages = [
    ("system", "당신은 영어를 한국어로 번역하는 데 도움이 되는 도우미입니다. 사용자 문장을 번역하세요."),
    ("human", "I love programming."),
]

ai_msg = llm.invoke(messages)

# %%
ai_msg
# Out:
# AIMessage(content='저는 프로그래밍을 좋아해요.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b82ca-99f7-7681-86ba-1431b30ddaec-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 30, 'output_tokens': 8, 'total_tokens': 38, 'input_token_details': {'cache_read': 0}})

# %%
ai_msg.content
# Out:
# '저는 프로그래밍을 좋아해요.'

# %% [markdown]
# ### 멀티 모달

# %%
from langchain.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3-flash-preview")

message = HumanMessage(
    content=[
        {"type": "text", "text": "Describe the image at the URL. 한국어로 설명하시오."},
        {
            "type": "image",
            "url": "https://picsum.photos/seed/picsum/200/300",
        },
    ]
)
response = model.invoke([message])

# %%
response.content[0]['text']
# Out:
# '이 이미지는 일출이나 일몰 시간대의 아름다운 설산 풍경을 담고 있습니다. 사진의 주요 특징은 다음과 같습니다:\n\n1.  **하늘**: 부드러운 분홍색, 은은한 주황색, 그리고 옅은 보라색과 푸른색이 어우러진 파스텔 톤의 하늘이 화면의 대부분을 차지하고 있습니다. 얇고 긴 구름들이 흩어져 있어 몽환적인 분위기를 자아냅니다.\n2.  **산봉우리**: 오른쪽 하단에는 눈과 바위로 덮인 뾰족하고 가파른 산봉우리가 솟아 있습니다. 낮은 각도에서 비치는 햇빛이 봉우리의 한쪽 면을 밝게 비추어 입체감을 더해줍니다.\n3.  **전경**: 아래쪽에는 짙은 푸른색 그림자가 드리워진 매끄러운 눈 언덕이 완만한 곡선을 그리며 배치되어 있습니다.\n4.  **분위기**: 전체적으로 매우 고요하고 평화로우며, 대자연의 웅장함과 겨울의 차가운 공기가 느껴지는 감성적인 사진입니다.'

# %%
import base64

with open("data/image.jpg", "rb") as img_file:
    encoded_img = base64.b64encode(img_file.read()).decode("utf-8")

# %%
encoded_img

# %%
from langchain.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3-flash-preview")

message = HumanMessage(
    content=[
        {"type": "text", "text": "Describe the image at the URL. 한국어로 설명하시오."},
        {
            "type": "image_url",
            "image_url": {"url": f"data:image/png;base64,{encoded_img}"},
        },
    ]
)
response = model.invoke([message])

# %%
response.content[0]['text']
# Out:
# "제시된 이미지는 빈센트 반 고흐의 대표작인 **'별이 빛나는 밤(The Starry Night)'**입니다. 이 작품의 주요 특징은 다음과 같습니다.\n\n1.  **하늘과 별**: 화면의 윗부분은 역동적으로 소용돌이치는 밤하늘이 지배하고 있습니다. 짙은 파란색과 하늘색이 뒤섞인 붓터치는 마치 파도가 치는 듯한 에너지를 느끼게 합니다. 오른쪽 상단에는 밝게 빛나는 노란색 초승달이 자리 잡고 있으며, 하늘 곳곳에는 후광에 둘러싸인 밝은 별들이 흩어져 있습니다.\n2.  **사이프러스 나무**: 왼쪽 전경에는 마치 타오르는 검은 불꽃처럼 보이는 거대한 사이프러스 나무가 하늘을 향해 높게 솟아 있습니다. 이 나무는 그림 전체의 수직적 균형을 잡아주며 다소 불안하면서도 강렬한 인상을 줍니다.\n3.  **마을과 산**: 하단에는 평화롭고 고요한 마을의 풍경이 담겨 있습니다. 뾰족한 첨탑이 있는 교회가 중심을 잡고 있으며, 마을 뒤쪽으로는 완만한 곡선을 그리는 짙은 푸른색의 산맥이 이어집니다.\n4.  **기법과 분위기**: 고흐 특유의 두껍고 짧은 붓터치(임파스토 기법)가 캔버스 전체에 살아있어 강한 생동감을 줍니다. 요동치는 하늘의 환상적인 움직임과 대조적으로 정적인 마을의 모습이 어우러져, 작가의 복잡한 내면세계와 고독하면서도 열정적인 감정을 잘 보여줍니다."
