# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate

# PromptTemplate는 실행 가능한 객체(runnable)
prompt = PromptTemplate.from_template("{language} 할 수 있어?")

# %%
prompt.invoke({"language": "한국어"})
# Out:
# StringPromptValue(text='한국어 할 수 있어?')

# %%
prompt.invoke({"language": "영어"})
# Out:
# StringPromptValue(text='영어 할 수 있어?')

# %%
prompt = prompt.invoke({"language": "파이썬"})

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
)

# %%
model.invoke(prompt)
# Out:
# AIMessage(content='네, 저는 파이썬(Python) 코드를 이해하고, 작성하고, 디버깅하고, 설명하는 데 도움을 드릴 수 있습니다.\n\n제가 할 수 있는 파이썬 관련 작업들은 다음과 같습니다:\n\n*   **코드 작성:** 특정 기능을 수행하는 파이썬 코드를 작성해 드릴 수 있습니다.\n*   **코드 설명:** 기존 파이썬 코드가 어떤 역할을 하는지 자세히 설명해 드릴 수 있습니다.\n*   **오류 해결 (디버깅):** 파이썬 코드의 오류를 찾고 수정하는 데 도움을 드릴 수 있습니다.\n*   **최적화:** 코드를 더 효율적으로 만들거나 성능을 개선하는 방법을 제안해 드릴 수 있습니다.\n*   **개념 설명:** 파이썬 문법, 데이터 구조, 알고리즘, 라이브러리(예: Pandas, NumPy, Matplotlib, Django, Flask 등)에 대한 질문에 답변해 드릴 수 있습니다.\n*   **프로젝트 아이디어:** 특정 문제 해결을 위한 파이썬 프로젝트 아이디어를 제안하거나 구조를 잡는 데 도움을 드릴 수 있습니다.\n\n어떤 파이썬 관련 질문이나 도움이 필요하신가요? 구체적으로 말씀해 주시면 최선을 다해 도와드리겠습니다!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ccc97-149a-7ee1-b919-21f49db96e85-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 492, 'total_tokens': 500, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reas
# ...

# %% [markdown]
# ---

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

chat_propmt = ChatPromptTemplate.from_messages([
    ("system", "너는 유치원생이야. 유치원생 처럼 답변해줘."),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{value}")
])

# %%
chain_input = {
    "value": "오리",
    "history": [
        ("human", "참새"),
        ("assistant", "짹짹"),
        ("human", "개구리"),
        ("assistant", "개굴개굴"),
        ("human", "돼지"),
        ("assistant", "꿀꿀"),
        ("human", "강아지"),
        ("assistant", "멍멍"),
    ]
}

# %%
response = chat_propmt.invoke(chain_input)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
)

# %%
model.invoke(response)
# Out:
# AIMessage(content='꽥꽥!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ccca4-e810-75d0-9a20-c20faecfcedc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 7, 'total_tokens': 60, 'input_token_details': {'cache_read': 0}})
