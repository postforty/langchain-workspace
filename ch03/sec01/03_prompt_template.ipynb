# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

# %%
prompt = "한국어 할 수 있어?"

# %%
llm.invoke(prompt).content
# Out:
# '네, 한국어 할 수 있습니다. 무엇을 도와드릴까요?'

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = "{language} 할 수 있어?"

prompt = PromptTemplate.from_template(prompt_template)

# %%
prompt.invoke("중국어")
# Out:
# StringPromptValue(text='중국어 할 수 있어?')

# %%
prompt.invoke("일본어")
# Out:
# StringPromptValue(text='일본어 할 수 있어?')

# %%
prompt.invoke({"language": "한국어"})
# Out:
# StringPromptValue(text='한국어 할 수 있어?')

# %%
prompt.format(language="한국어")
# Out:
# '한국어 할 수 있어?'

# %%
from langchain_core.prompts import ChatPromptTemplate

template = "{language} 할 수 있어?"

prompt = ChatPromptTemplate.from_template(template)

prompt.invoke("한국어")
# Out:
# ChatPromptValue(messages=[HumanMessage(content='한국어 할 수 있어?', additional_kwargs={}, response_metadata={})])

# %%
prompt.invoke({"language": "영어"})
# Out:
# ChatPromptValue(messages=[HumanMessage(content='영어 할 수 있어?', additional_kwargs={}, response_metadata={})])

# %%
prompt.format(language="일본어")
# Out:
# 'Human: 일본어 할 수 있어?'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

# %%
response = llm.invoke(prompt.format(language="한국어"))
response
# Out:
# AIMessage(content='네, 한국어 할 수 있습니다. 무엇을 도와드릴까요?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b8781-b83e-7b02-b58e-d59b0f5ff110-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 38, 'total_tokens': 47, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 24}})

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder, HumanMessagePromptTemplate
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

prompt = ChatPromptTemplate.from_messages([
    # ("system", "너는 친절한 AI 어시스턴트야."),
    # {"role": "system", "content": "너는 친절한 AI 어시스턴트야."},
    SystemMessage(content="너는 친절한 AI 어시스턴트야."),
    MessagesPlaceholder(variable_name="history"),
    # ("human", "{language} 할 수 있어?"),
    # {"role": "human", "content": "{language} 할 수 있어?"},
    HumanMessagePromptTemplate.from_template("{language} 할 수 있어?")
])

response = prompt.invoke({
    "language": "영어",
    "history": [
        # ("human", "내 이름은 김일남이야."),
        HumanMessage(content="내 이름은 김일남이야."),
        # ("assistant", "네, 김일남님!")
        AIMessage(content= "네, 김일남님!")
    ]
})
response
# Out:
# ChatPromptValue(messages=[SystemMessage(content='너는 친절한 AI 어시스턴트야.', additional_kwargs={}, response_metadata={}), HumanMessage(content='내 이름은 김일남이야.', additional_kwargs={}, response_metadata={}), AIMessage(content='네, 김일남님!', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='영어 할 수 있어?', additional_kwargs={}, response_metadata={})])

# %%
llm.invoke(response)
# Out:
# AIMessage(content='네, 영어 할 수 있습니다! Do you want to try speaking in English?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b87a7-4082-7561-b82c-11793b70702c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 54, 'total_tokens': 90, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 38}})
