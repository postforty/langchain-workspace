# %%
import os
from dotenv import load_dotenv
load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.1, # 창의성 (0.0~2.0)
    google_api_key=gemini_api_key
)

# %%
from langchain_core.prompts import PromptTemplate

template = "{language} 할 수 있어?"

prompt = PromptTemplate.from_template(template)

# %%
prompt
# Out:
# PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='{language} 할 수 있어?')

# %%
kor_prompt = prompt.format(language="한국말")

# %%
response = llm.invoke(kor_prompt)

# %%
response.content
# Out:
# '네, 한국말 할 수 있습니다. 저는 구글에서 훈련받은 대규모 언어 모델이며, 한국어로 질문하시면 이해하고 답변해 드릴 수 있습니다.'
