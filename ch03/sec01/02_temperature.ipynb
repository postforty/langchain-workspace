# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    temperature=0, # 0에 가까울 수록 일관성 있는 답변 생성
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
ai_msg = model.invoke(prompt)
ai_msg
# Out:
# AIMessage(content=[{'type': 'text', 'text': '어느 날, 꼬마 개발자는 똑똑한 에이전트를 만들기로 했습니다. 먼저 **PromptTemplate**으로 지식의 틀을 잡고, **Memory**를 심어 과거의 대화를 기억하게 했죠. 마지막으로 여러 도구를 엮는 **Chain**을 연결하자 에이전트가 눈을 떴습니다. 어느 날, 에이전트는 서버 오류가 아닌, 길 잃은 고양이의 울음소리 주파수를 분석해 주인의 집 위치를 정확히 찾아내어 모두를 놀라게 했습니다.', 'extras': {'signature': 'EjQKMgEMOdbH+mMmo13riflfuoZH0Oyf9taBbLnEXN9nLfnUW+751v1RIQGuxuFeqaTBaj9U'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dec46-d53e-7dd0-9378-ef58ddaa49b0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 124, 'output_tokens': 119, 'total_tokens': 243, 'input_token_details': {'cache_read': 0}})

# %%
ai_msg.content[0].get("text")
# Out:
# '어느 날, 꼬마 개발자는 똑똑한 에이전트를 만들기로 했습니다. 먼저 **PromptTemplate**으로 지식의 틀을 잡고, **Memory**를 심어 과거의 대화를 기억하게 했죠. 마지막으로 여러 도구를 엮는 **Chain**을 연결하자 에이전트가 눈을 떴습니다. 어느 날, 에이전트는 서버 오류가 아닌, 길 잃은 고양이의 울음소리 주파수를 분석해 주인의 집 위치를 정확히 찾아내어 모두를 놀라게 했습니다.'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    temperature=2, # 2에 가까울 수록 창의적인 답변 생성
)

# %%
ai_msg = model.invoke(prompt)
ai_msg
# Out:
# AIMessage(content=[{'type': 'text', 'text': "작은 요리사 에이전트를 만드는 날이었습니다. 나는 요리책에서 영감을 얻은 'PromptTemplate'으로 그에게 임무를 주고, 그동안의 조리 비법을 기억할 'Memory'를 심었습니다. 복잡한 명령들을 하나의 'Chain'으로 엮어 논리적 뼈대를 완성하자, 에이전트는 생명력을 얻어 움직였습니다. 완벽한 요리를 만들길 기대했으나, 뜻밖에도 에이전트는 창밖에서 꼬인 인터넷 회선을 요리하듯 꼬아 0.1초 만에 끊어진 통신을 복구하며 세상을 구했습니다.", 'extras': {'signature': 'EjQKMgEMOdbHBRqkfKQa2xic1c+sFn7Vm8RFRkH2sxDIw4J8OurPsMWw11o9viVJOVIe12ye'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dec46-db28-7093-829a-6eaeebe6cbae-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 124, 'output_tokens': 140, 'total_tokens': 264, 'input_token_details': {'cache_read': 0}})

# %%
ai_msg.content[0].get("text")
# Out:
# "작은 요리사 에이전트를 만드는 날이었습니다. 나는 요리책에서 영감을 얻은 'PromptTemplate'으로 그에게 임무를 주고, 그동안의 조리 비법을 기억할 'Memory'를 심었습니다. 복잡한 명령들을 하나의 'Chain'으로 엮어 논리적 뼈대를 완성하자, 에이전트는 생명력을 얻어 움직였습니다. 완벽한 요리를 만들길 기대했으나, 뜻밖에도 에이전트는 창밖에서 꼬인 인터넷 회선을 요리하듯 꼬아 0.1초 만에 끊어진 통신을 복구하며 세상을 구했습니다."
