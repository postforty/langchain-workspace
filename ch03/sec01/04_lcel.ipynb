# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template("{language} 할 수 있어?")

# %%
prompt.invoke("한국말")
# Out:
# StringPromptValue(text='한국말 할 수 있어?')

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
)

# %%
# chain 구성
chain = prompt | model

# %%
chain.invoke("한국말")
# Out:
# AIMessage(content=[{'type': 'text', 'text': '네, 한국말 할 수 있어요! 어떤 도움이 필요하신가요? 궁금한 점이 있으면 무엇이든 물어보세요.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ceac7-2ef4-79f1-8d50-e96bf98c715f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 238, 'total_tokens': 245, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 210}})

# %% [markdown]
# ---

# %%
template = "{topic}에 대해 아주 쉽게 설명해줘."

prompt = PromptTemplate.from_template(template)

# %%
chain = prompt | model

# %%
res = chain.stream({"topic": "랭체인"})

# %%
result = next(res)

# %%
result.content[0]["text"]
# Out:
# '**랭체인(LangChain)**을 아주 쉽게 비유를'

# %%
next(res)
# Out:
# AIMessageChunk(content=[{'type': 'text', 'text': '\n\n---\n\n### 1. 한 줄 요약\n**"챗GPT 같은 인공지능(LLM)을 우리가', 'index': 0}], additional_kwargs={}, response_metadata={'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ceacb-219b-7dc1-a4cd-e4cc27c6be7f', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_token_details': {'cache_read': 0}, 'total_tokens': 27, 'output_token_details': {'reasoning': 0}, 'input_tokens': 0, 'output_tokens': 27}, tool_call_chunks=[])

# %%
for token in res:
    print(token.content[0]["text"], end="", flush=True)
# Out:
#  들어 설명해 드릴게요.
#
# ---
#
# ### 1. 한 줄 요약
# **"똑똑하지만 세상 물정 모르는 챗GPT(AI)에게 여러 가지 도구를 쥐여주고, 일을 시키는 '매니저' 혹은 '레고 조립 세트'입니다."**
#
# ---
#
# ### 2. 왜 랭체인이 필요한가요? (비유)
# 챗GPT 같은 AI(LLM)는 마치 **"천재지만 방 안에만 갇혀 있는 박사님"**과 같습니다.
# 이 박사님은 아는 건 많지만, 몇 가지 치명적인 단점이 있어요.
#
# 1.  **기억력이 짧음:** 방금 한 말을 금방 잊어버리기도 합니다.
# 2.  **최신 정보를 모름:** 학습한 데이터 이후의 세상 일은 모릅니다.
# 3.  **내 개인 문서를 모름:** 우리 회사 문서나 내 일기장 내용은 모릅니다.
# 4.  **행동을 못 함:** 말은 잘하지만, 직접 엑셀을 만들거나 이메일을 보내지는 못합니다.
#
# **랭체인은 이 박사님(AI)에게 손과 발, 그리고 최신 백과사전을 쥐여주는 역할을 합니다.**
#
# ---
#
# ### 3. 랭체인이 하는 주요 역할 (핵심 기능)
#
# 랭체인은 여러 부품을 **'사슬(Chain)'**처럼 엮어서 하나의 완성된 시스템을 만듭니다.
#
# 1.  **데이터 연결 (최신 정보 알려주기):**
#     박사님에게 최신 신문이나 우리 회사 PDF 파일을 읽게 한 뒤, "이 내용에 기반해서 답변해줘"라고 시킵니다.
# 2.  **기억력 부여 (메모리):**
#     대화 내용을 별도의 노트에 적어두었다가, 다음에 질문할 때 박사님에게 슬쩍 보여줍니다. (대화의 흐름을 유지)
# 3.  **도구 사용 (에이전트):**
#     박사님이 "계산이 필요해"라고 하면 계산기를 빌려주고, "날씨를 알아야 해"라고 하면 인터넷 검색창을 띄워줍니다.
# 4.  **순서 정하기 (체인):**
#     "1번: 번역해, 2번: 요약해, 3번: 이메일로 써줘" 같은 순서를 미리 정해놓고 자동으로 실행하게 합니다.
#
# ---
#
# ### 4. 예를 들어볼까요?
#
# **[랭체인 없이 챗GPT만 쓸 때]**
# *   나: "우리 회사 작년 매출이 얼마였지?"
# *   AI: "저는 당신의 회사 내부 데이터를 알 수 없습니다."
#
# **[랭체인으로 만든 프로그램을 쓸 때]**
# 1.  **랭체인**이 우리 회사 매출 엑셀 파일을 읽어옵니다.
# 2.  그 내용을 **AI**에게 전달합니다.
# 3.  **AI**가 내용을 분석합니다.
# 4.  **나**에게 답변합니다: "작년 매출은 100억원이었습니다!"
#
# ---
#
# ### 5. 마무리
# 결국 **랭체인**은 개발자들이 **AI를 이용해 진짜 쓸모 있는 서비스(앱, 프로그램)를 아주 쉽고 빠르게 만들 수 있도록 도와주는 도구 상자**라고 이해하시면 됩니다.
#
# *   **AI** = 엔진
# *   **랭체인** = 바퀴, 핸들, 브레이크 등을 연결해 **자동차**를 만드는 프레임워크
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 for token in res:
# ----> 2     print(token.content[0]["text"], end="", flush=True)
#
# IndexError: list index out of range
