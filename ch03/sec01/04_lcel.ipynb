# %% [markdown]
# ### LCEL(LangChain Expression Language)

# %%
import os
from dotenv import load_dotenv
load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.1, # 창의성 (0.0~2.0)
    google_api_key=gemini_api_key
)

# %%
from langchain_core.prompts import PromptTemplate

template = "{language} 할 수 있어?"

prompt = PromptTemplate.from_template(template)

# %%
chain = prompt | llm

# %%
chain.invoke({"language": "한국어"}).content
# Out:
# '네, 한국어 할 수 있습니다. 무엇을 도와드릴까요?'

# %% [markdown]
# ### 스트리밍 출력

# %%
template = "{topic}에 대해 쉽게 설명해줘."

prompt = PromptTemplate.from_template(template)

# %%
chain = prompt | llm

# %%
response = chain.stream({"topic": "LangChain"})

# %%
for token in response:
    print(token.content, end="", flush=True)
# Out:
# LangChain에 대해 쉽게 설명해 드릴게요!
#
# ---
#
# **LangChain은 '거대 언어 모델(LLM)'을 활용해서 똑똑한 애플리케이션을 만들 수 있도록 도와주는 '도구 상자' 또는 '프레임워크'입니다.**
#
# 이게 무슨 말이냐고요? 비유를 들어 설명해 드릴게요.
#
# ---
#
# ### 🧠 LLM은 똑똑한 '신입 사원'
#
# 우리가 흔히 아는 ChatGPT 같은 LLM은 정말 똑똑한 '뇌'를 가지고 있습니다. 마치 엄청나게 똑똑한 **'신입 사원'**이라고 생각해 보세요. 이 신입 사원은 방대한 지식을 가지고 있어서 어떤 질문이든 척척 대답할 수 있습니다.
#
# 하지만 이 신입 사원에게는 몇 가지 약점이 있습니다.
#
# 1.  **기억력이 없어요:** 방금 나눈 대화도 잊어버려요. (매번 새로운 대화처럼 시작)
# 2.  **세상 물정을 몰라요:** 실시간 정보나 인터넷 검색을 못 해요. (자신이 학습한 데이터까지만 앎)
# 3.  **행동을 못 해요:** 계산을 하거나, 이메일을 보내거나, 다른 프로그램을 실행할 수 없어요. (오직 텍스트 생성만 가능)
# 4.  **복잡한 일을 혼자 못 해요:** "이거 검색해서 요약하고, 그 다음에 저 사람한테 이메일 보내줘" 같은 여러 단계를 거쳐야 하는 일은 못 해요.
#
# ### 🛠️ LangChain은 '유능한 팀장'
#
# 여기서 LangChain이 등장합니다! LangChain은 이 똑똑한 신입 사원(LLM)을 **'유능한 팀장'**처럼 만들어주는 역할을 해요.
#
# LangChain은 LLM에게 다음과 같은 능력을 부여해 줍니다.
#
# 1.  **기억력 (Memory):**
#     *   "신입 사원아, 이전에 고객과 나눈 대화를 기억해 둬!"
#     *   **→ 이전 대화를 기억하게 해서 자연스러운 연속적인 대화가 가능하게 해요.** (챗봇이 이전 질문을 기억하고 답변하는 것처럼)
#
# 2.  **외부 정보 접근 (Retrieval/Tools):**
#     *   "신입 사원아, 지금 당장 인터넷에서 최신 정보를 검색해 봐!"
#     *   **→ 인터넷 검색, 데이터베이스 조회, 특정 문서 읽기 등 외부 정보를 찾아오게 할 수 있어요.** (LLM이 실시간 정보나 내 개인 문서를 참고해서 답변하도록)
#
# 3.  **도구 사용 (Tools):**
#     *   "신입 사원아, 계산이 필요하면 계산기를 쓰고, 이메일을 보내야 하면 이메일 발송기를 사용해!"
#     *   **→ 계산기, 코드 실행기, 이메일 발송기 등 다양한 '도구'를 LLM이 필요할 때 사용하게 해줘요.** (LLM이 단순히 말만 하는 게 아니라 실제 행동을 할 수 있도록)
#
# 4.  **여러 단계 연결 (Chains):**
#     *   "신입 사원아, 먼저 이 정보를 검색하고, 그 다음에 요약해서, 마지막으로 고객에게 답변해 줘."
#     *   **→ 하나의 질문에 대해 '검색 → 요약 → 답변'처럼 여러 단계를 거쳐서 답을 찾도록 지시할 수 있어요.** (복잡한 작업을 순서대로 처리)
#
# 5.  **스스로 판단하고 행동 (Agents):**
#     *   "신입 사원아, 어떤 질문이 들어왔을 때, 어떤 도구를 사용해야 할지, 어떤 단계를 거쳐야 할지 네가 알아서 판단해서 실행해 봐!"
#     *   **→ LLM 스스로 어떤 도구를 언제 사용할지, 어떤 순서로 일을 처리할지 판단해서 실행하게 만들 수 있어요.** (가장 똑똑한 형태의 LLM 애플리케이션)
#
# ---
#
# ### 💡 그래서 LangChain으로 뭘 할 수 있나요?
#
# LangChain을 사용하면 단순히 질문에 답하는 것을 넘어, 훨씬 더 유용하고 똑똑한 LLM 기반 애플리케이션을 만들 수 있습니다.
#
# *   **내 회사 문서 내용을 학습해서 질문에 답해주는 챗봇:** (외부 정보 접근 + 기억력)
# *   **실시간 주식 정보를 찾아 분석해주는 비서:** (외부 정보 접근 + 도구 사용)
# *   **복잡한 데이터를 분석하고 요약해주는 도구:** (여러 단계 연결 + 도구 사용)
# *   **사용자의 요청에 따라 이메일을 작성하고 보내는 에이전트:** (스스로 판단하고 행동 + 도구 사용)
#
# ---
#
# **결론적으로, LangChain은 LLM의 잠재력을 최대한 끌어내서, 단순히 질문에 답하는 것을 넘어 '실제로 유용한 일'을 할 수 있는 똑똑한 애플리케이션을 만들 수 있게 해주는 강력한 도구입니다.**
#
# LLM을 더 똑똑하고, 더 유용하게 만들어주는 '접착제'이자 '지휘자'라고 생각하시면 가장 쉽습니다.
