# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    "google_genai:gemini-3.1-flash-lite-preview",
)

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("당신은 시 전문가 입니다."),
    HumanMessage("봄에 관한 하이쿠를 작성해줘"),
    AIMessage("벚꽃이 피어나네..."),
]

# %%
response = model.invoke(messages)

# %%
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': '\n꽃잎이 흩날리며\n봄이 왔구나.'}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019decf9-79d4-7571-8e03-2abbb952b0b9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 26, 'output_tokens': 15, 'total_tokens': 41, 'input_token_details': {'cache_read': 0}})

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage, ToolMessage

ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "날씨_정보_가져오기",
        "args": {"위치": "부산"},
        "id": "call_123"
    }]
)

weather_result = "흐림, 17도"

tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"
)

messages = [
    HumanMessage("부산의 날씨는 어때요?"),
    ai_message,
    tool_message
]

# %%
response = model.invoke(messages)

# %%
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': '현재 부산은 흐린 날씨를 보이고 있으며, 기온은 17도입니다. 외출하실 때 참고하시기 바랍니다!', 'extras': {'signature': 'EjQKMgEMOdbHl8mRhR0EBJdAJtltAZIik93YUU9ADbZvVTs6m/HCT1QlhrnLUd/FuUEUGmzP'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019decff-0359-7771-b142-ed0529b082bf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 117, 'output_tokens': 30, 'total_tokens': 147, 'input_token_details': {'cache_read': 0}})
