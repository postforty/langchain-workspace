# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
# import os

# os.getenv("GOOGLE_API_KEY")

# %%
from langchain.tools import tool

# [도구 정의 방법]
# 1. 타입 힌팅
# 2. Docsting
# 3. tool 데코레이션
@tool
def get_weather(city: str) -> str:
    """특정 도시의 날씨를 가져옵니다."""
    return f"{city}: 맑음"

# %%
from langchain.agents import create_agent

agent = create_agent(model="google_genai:gemini-3-flash-preview", tools=[get_weather])

# %%
from langchain.messages import SystemMessage, HumanMessage

agent.invoke({
    "messages": [HumanMessage(content="내 이름은 김일남이야.")]
})
# Out:
# {'messages': [HumanMessage(content='내 이름은 김일남이야.', additional_kwargs={}, response_metadata={}, id='28a733ce-34b4-477b-b6fd-bf9cb4b00077'),
#   AIMessage(content=[{'type': 'text', 'text': '반가워요, 김일남 님! 만나서 반갑습니다. 오늘 제가 도와드릴 일이 있을까요? 무엇이든 편하게 말씀해 주세요!', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf030-5042-7b40-a767-cb20819c2678-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 57, 'output_tokens': 216, 'total_tokens': 273, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 184}})]}

# %%
from langchain.messages import SystemMessage, HumanMessage

agent.invoke({
    "messages": [HumanMessage(content="부산의 날씨를 알려주세요.")]
})
# Out:
# {'messages': [HumanMessage(content='부산의 날씨를 알려주세요.', additional_kwargs={}, response_metadata={}, id='60f26120-f382-4b8f-90f8-9fc195a14555'),
#   AIMessage(content=[], additional_kwargs={'function_call': {'name': 'get_weather', 'arguments': '{"city": "\\ubd80\\uc0b0"}'}, '__gemini_function_call_thought_signatures__': {'f61e8d65-ded4-4ebc-9f21-090a6d45a390': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf031-3d8b-7ab3-bc19-2f73c1952a2a-0', tool_calls=[{'name': 'get_weather', 'args': {'city': '부산'}, 'id': 'f61e8d65-ded4-4ebc-9f21-090a6d45a390', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 58, 'output_tokens': 72, 'total_tokens': 130, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 56}}),
#   ToolMessage(content='부산: 맑음', name='get_weather', id='522222ab-4d8c-478c-adde-6950d14f71cd', tool_call_id='f61e8d65-ded4-4ebc-9f21-090a6d45a390'),
#   AIMessage(content=[{'type': 'text', 'text': '부산의 날씨는 현재 맑습니다.'}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cf031-4346-7172-99d4-d3f656968ae9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 148, 'output_tokens': 10, 'total_tokens': 158, 'input_token_details': {'cache_read': 0}})]}
