# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from pydantic import BaseModel, Field

class MovieInfo(BaseModel):
    """영화에 대한 세부 정보"""
    title: str = Field(description="영화의 제목")
    year: int = Field(description="영화의 개봉된 연도")
    director: str = Field(description="영화의 감독")
    rating: float = Field(description="10점 만점 영화 평점")

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="google_genai:gemini-3.1-flash-lite",
    response_format=MovieInfo
)
# Out:
# d:\wsh\langchain-workspace\ch04\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
response = agent.invoke(
    {"messages": [{"role": "user", "content": "영화 기생충에 대한 세부 정보를 제공해줘"}]},
)

# %%
response
# Out:
# {'messages': [HumanMessage(content='영화 기생충에 대한 세부 정보를 제공해줘', additional_kwargs={}, response_metadata={}, id='f30d4cc6-fe79-4117-bcac-116a6947250f'),
#   AIMessage(content=[], additional_kwargs={'function_call': {'name': 'MovieInfo', 'arguments': '{"rating": 9.07, "title": "\\uae30\\uc0dd\\ucda9", "year": 2019, "director": "\\ubd09\\uc900\\ud638"}'}, '__gemini_function_call_thought_signatures__': {'26257d9f-5564-4659-821b-c0a7195995f1': 'EjQKMgEMOdbHkD5gc/MrQBTFLShpBzOyybrx+q6GPvi+XP1O85qw7hysbIsQkWzcOc0AYfR/'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e1066-15d7-7fa2-b84f-fc428ac1388d-0', tool_calls=[{'name': 'MovieInfo', 'args': {'rating': 9.07, 'title': '기생충', 'year': 2019, 'director': '봉준호'}, 'id': '26257d9f-5564-4659-821b-c0a7195995f1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 132, 'output_tokens': 39, 'total_tokens': 171, 'input_token_details': {'cache_read': 0}}),
#   ToolMessage(content="Returning structured response: title='기생충' year=2019 director='봉준호' rating=9.07", name='MovieInfo', id='d92a2ba8-10c7-47c1-a4de-420adc533f0e', tool_call_id='26257d9f-5564-4659-821b-c0a7195995f1')],
#  'structured_response': MovieInfo(title='기생충', year=2019, director='봉준호', rating=9.07)}

# %%
response["structured_response"]
# Out:
# MovieInfo(title='기생충', year=2019, director='봉준호', rating=9.07)

# %%
response["structured_response"].director
# Out:
# '봉준호'
