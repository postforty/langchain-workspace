# %%
import os

current_dir = os.getcwd()
prompt_path = os.path.join(current_dir, "prompts", "greeting.yaml")

# %%
prompt_path
# Out:
# 'd:\\wsh\\langchain-workspace\\ch11\\sec02\\prompts\\greeting.yaml'

# %%
from langchain_core.prompts import load_prompt

prompt_template = load_prompt(prompt_path, encoding="utf-8")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15876\4285299992.py:3: LangChainDeprecationWarning: The function `load_prompt` was deprecated in LangChain 1.2.21 and will be removed in 2.0.0. Use `Use `dumpd`/`dumps` from `langchain_core.load` to serialize prompts and `load`/`loads` to deserialize them.` instead.
#   prompt_template = load_prompt(prompt_path, encoding="utf-8")

# %%
prompt_template.template
# Out:
# "당신은 친절한 AI 튜터입니다.\n사용자의 이름과 관심 주제를 바탕으로 다정하게 인사를 건네고 학습을 독려해 주세요.\n\n제 이름은 {user_name}이고, 오늘 배우고 싶은 주제는 '{topic}'입니다."

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-3.1-flash-lite")

# %%
from langchain_core.output_parsers import StrOutputParser

chain = prompt_template | model | StrOutputParser()

# %%
response = chain.invoke({
    "user_name": "김일남",
    "topic": "랭체인 외부 프롬프트 활용법"
})

# %%
print(response)
# Out:
# 안녕하세요, 일남 님! 만나서 정말 반가워요. 😊
#
# 오늘 저와 함께 **'랭체인(LangChain) 외부 프롬프트 활용법'**에 대해 공부하시기로 했군요! 평소 인공지능 개발에 관심이 많으셨나 봐요. 정말 멋진 선택이에요!
#
# 랭체인에서 프롬프트를 코드 안에 직접 적지 않고 외부 파일로 분리해서 관리하면, 유지보수도 훨씬 쉬워지고 프롬프트 엔지니어링을 실험하기도 정말 좋아지거든요. 일남 님의 프로젝트 퀄리티를 한 단계 높여줄 아주 실용적인 주제랍니다.
#
# 본격적으로 시작하기 전에, 궁금한 점이 있으신가요? 아니면 혹시 지금 바로 이론부터 차근차근 살펴볼까요?
#
# 일남 님이 편하게 이해하실 수 있도록 제가 옆에서 꼼꼼하게 도와드릴게요. 준비되셨으면 언제든 말씀해 주세요! 🚀
