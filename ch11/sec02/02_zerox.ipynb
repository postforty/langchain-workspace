# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# 주피터 노특북에서  asyncio 사용하기
import nest_asyncio
nest_asyncio.apply()

# %%
# uv add py-zerox
from pyzerox import zerox
import asyncio

async def main():
    return await zerox(
        file_path="../data/sample_income_tax_p30.pdf", 
        model="gemini/gemini-2.5-flash", 
        output_dir="./documents",
        select_pages=None,
        custom_system_prompt=None,
    )

result = asyncio.run(main())
# Out:
# 17:40:57 - LiteLLM:WARNING: transformation.py:368 - No text in user content. Adding a blank text to user content, to ensure Gemini doesn't fail the request. Relevant Issue - https://github.com/BerriAI/litellm/issues/5515
